# %%
# a bunch of scratch work used to generate tables, hand tuning and combine results
import os 
import sys 
import time 
import numpy as np
import json
import tpch_param as tp

# %%
# hand tuning = pick the lowest time for each param after one deterministic run
fnames = ['sf10_n10_det_main0.txt', 'sf10_n10_det_main_fix.txt']#
#['sf1_n10_det_main2.txt', 'sf1_n10_det_main.txt']
direc = './training_results'
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if x in fnames]
param_val = {} #fname -> param_val -> list of times
names = []
params = []
for FNAME in training_fnames:
    print(FNAME)
    param_val[FNAME] = {}
    with open(FNAME, "r") as file:
        for line in file:
            d = eval(line)

            params = [p for p in d["params"] if p['spark_param']]
            names = [p['name'] for p in d["params"] if p['spark_param']]
            runtimes = d["runtimes"]
            if len(runtimes) == 0:
                continue

            all_default = True
            varying_param = 'default'
            varying_val = ''
            for p in params:
                if str(p['cur_value']) != str(p['default_value']):
                    varying_param = p['name']
                    varying_val = p['cur_value']
                    all_default = False
                    break
            param_val[FNAME].setdefault(f'{varying_param}_{varying_val}',[]).append(runtimes)
# Out:
# ./training_results/sf10_n10_det_main0.txt
# ./training_results/sf10_n10_det_main_fix.txt

# %%
pvals = {} # fname -> param -> best val
for FNAME in param_val:
    print(FNAME)
    pvals[FNAME] = {}
    afname = "AVG_"+FNAME
    pvals[afname] = {}
    for pname in sorted(names):
        
        defa = [p['default_value'] for p in params if p['name'] == pname][0]
        print(pname, ": --- ", defa)
        vals = [(np.median([x['total'] for x in rt]), pv) for pv, rt in param_val[FNAME].items() if pname in pv or pv == 'default_']
        vals = sorted(vals)
        if vals[0][1] == 'default_':
            pvals[FNAME][pname] = defa
        else:
            pvals[FNAME][pname] = vals[0][1].split("_")[1] 
        
        avg_vals = [(np.average([x['total'] for x in rt]), pv) for pv, rt in param_val[FNAME].items() if pname in pv or pv == 'default_']
        avg_vals = sorted(avg_vals)
        if avg_vals[0][1] == 'default_':
            pvals[afname][pname] = defa
        else:
            pvals[afname][pname] = avg_vals[0][1].split("_")[1] 
            
        for i, v in enumerate(vals):
            print(f'{v[1]}: {round(v[0], 3)} sec,  AVG {avg_vals[i][1].split("_")[1]}: {round(avg_vals[i][0], 3)} sec, {len(param_val[FNAME][v[1]] if "default" not in v[1] else param_val[FNAME]["default_"])}')
        print("---")
# Out:
# ./training_results/sf10_n10_det_main0.txt
# spark.broadcast.blockSize : ---  4m
# default_: 182.216 sec,  AVG 24m: 192.952 sec, 9
# spark.broadcast.blockSize_6m: 183.542 sec,  AVG 22m: 193.117 sec, 8
# spark.broadcast.blockSize_8m: 183.819 sec,  AVG 6m: 196.05 sec, 8
# spark.broadcast.blockSize_16m: 183.926 sec,  AVG 16m: 198.039 sec, 8
# spark.broadcast.blockSize_14m: 184.34 sec,  AVG 14m: 198.331 sec, 8
# spark.broadcast.blockSize_10m: 184.549 sec,  AVG 8m: 198.667 sec, 8
# spark.broadcast.blockSize_22m: 184.917 sec,  AVG 10m: 199.128 sec, 8
# spark.broadcast.blockSize_12m: 185.238 sec,  AVG 12m: 199.159 sec, 8
# spark.broadcast.blockSize_18m: 185.282 sec,  AVG 20m: 211.219 sec, 8
# spark.broadcast.blockSize_24m: 185.908 sec,  AVG : 215.921 sec, 8
# spark.broadcast.blockSize_20m: 187.847 sec,  AVG 18m: 241.219 sec, 8
# ---
# spark.broadcast.compress : ---  true
# default_: 182.216 sec,  AVG false: 193.714 sec, 9
# spark.broadcast.compress_false: 184.204 sec,  AVG : 215.921 sec, 8
# ---
# spark.default.parallelism : ---  200
# spark.default.parallelism_60: 180.385 sec,  AVG 60: 186.227 sec, 9
# spark.default.parallelism_140: 180.715 sec,  AVG 100: 190.582 sec, 9
# spark.default.parallelism_300: 181.386 sec,  AVG 140: 211.853 sec, 9
# spark.default.parallelism_100: 181.66 sec,  AVG 180: 213.767 sec, 9
# spark.default.parallelism_180: 182.054 sec,  AVG 220: 214.772 sec, 9
# default_: 182.216 sec,  AVG : 215.921 sec, 9
# spark.default.parallelism_220: 182.341 sec,  AVG 260: 216.188 sec, 9
# spark.default.parallelism_260: 183.028 sec,  AVG 340: 218.07 sec, 9
# spark.default.parallelism_340: 186.124 sec,  AVG 300: 218.183 sec, 9
# spark.default.parallelism_380: 186.906 sec,  AVG 380: 219.327 sec, 9
# spark.default.parallelism_20: 255.713 sec,  AVG 20: 255.713 sec, 9
# ---
# spark.driver.cores : ---  1
# default_: 182.216 sec,  AVG 4: 197.106 sec, 9
# spark.driver.cores_4: 183.777 sec,  AVG 3: 197.494 sec, 8
# spark.driver.cores_3: 184.705 sec,  AVG 2: 198.928 sec, 8
# spark.driver.cores_2: 185.021 sec,  AVG : 215.921 sec, 8
# ---
# spark.driver.memory : ---  1g
# spark.driver.memory_3g: 122.023 sec,  AVG 4g: 141.821 sec, 8
# spark.driver.memory_4g: 122.065 sec,  AVG 3g: 144.275 sec, 8
# spark.driver.memory_2g: 135.446 sec,  AVG 2g: 154.649 sec, 8
# default_: 182.216 sec,  AVG : 215.921 sec, 9
# ---
# spark.executor.cores : ---  1
# spark.executor.cores_6: 182.136 sec,  AVG 6: 214.321 sec, 9
# default_: 182.216 sec,  AVG 8: 215.685 sec, 9
# spark.executor.cores_5: 182.55 sec,  AVG : 215.921 sec, 9
# spark.executor.cores_8: 182.592 sec,  AVG 3: 216.478 sec, 9
# spark.executor.cores_3: 183.402 sec,  AVG 5: 216.633 sec, 9
# spark.executor.cores_7: 184.45 sec,  AVG 2: 217.637 sec, 9
# spark.executor.cores_4: 184.605 sec,  AVG 4: 217.641 sec, 9
# spark.executor.cores_2: 184.645 sec,  AVG 7: 221.307 sec, 9
# ---
# spark.executor.instances : ---  2
# spark.executor.instances_6: 181.464 sec,  AVG 8: 198.738 sec, 9
# default_: 182.216 sec,  AVG : 215.921 sec, 9
# spark.executor.instances_7: 183.582 sec,  AVG 5: 218.617 sec, 9
# spark.executor.instances_5: 184.621 sec,  AVG 6: 220.56 sec, 9
# spark.executor.instances_3: 185.211 sec,  AVG 4: 220.953 sec, 9
# spark.executor.instances_8: 185.615 sec,  AVG 7: 221.686 sec, 8
# spark.executor.instances_4: 186.409 sec,  AVG 3: 221.981 sec, 9
# ---
# spark.executor.memory : ---  1g
# spark.executor.memory_5g: 181.35 sec,  AVG : 215.921 sec, 9
# default_: 182.216 sec,  AVG 5g: 216.636 sec, 9
# spark.executor.memory_6g: 182.543 sec,  AVG 3g: 216.869 sec, 9
# spark.executor.memory_8g: 183.14 sec,  AVG 4g: 217.026 sec, 9
# spark.executor.memory_4g: 184.211 sec,  AVG 2g: 217.599 sec, 9
# spark.executor.memory_3g: 185.266 sec,  AVG 6g: 219.312 sec, 9
# spark.executor.memory_7g: 185.527 sec,  AVG 8g: 221.589 sec, 9
# spark.executor.memory_2g: 185.954 sec,  AVG 7g: 224.272 sec, 9
# ---
# spark.io.compression.codec : ---  lz4
# default_: 182.216 sec,  AVG snappy: 195.977 sec, 9
# spark.io.compression.codec_snappy: 190.127 sec,  AVG : 215.921 sec, 8
# ---
# spark.memory.fraction : ---  0.6
# spark.memory.fraction_0.5: 180.966 sec,  AVG 0.5: 189.468 sec, 8
# default_: 182.216 sec,  AVG 0.7: 193.478 sec, 9
# spark.memory.fraction_0.4: 186.629 sec,  AVG 0.4: 194.731 sec, 8
# spark.memory.fraction_0.7: 187.966 sec,  AVG 0.8: 197.886 sec, 8
# spark.memory.fraction_0.3: 192.111 sec,  AVG 0.3: 199.061 sec, 8
# spark.memory.fraction_0.8: 193.426 sec,  AVG : 215.921 sec, 8
# ---
# spark.memory.storageFraction : ---  0.5
# default_: 182.216 sec,  AVG 0.8: 212.786 sec, 9
# spark.memory.storageFraction_0.8: 182.698 sec,  AVG 0.4: 213.496 sec, 8
# spark.memory.storageFraction_0.7: 183.412 sec,  AVG 0.3: 213.873 sec, 8
# spark.memory.storageFraction_0.6: 183.544 sec,  AVG 0.7: 214.019 sec, 8
# spark.memory.storageFraction_0.4: 184.675 sec,  AVG 0.6: 215.275 sec, 8
# spark.memory.storageFraction_0.3: 185.76 sec,  AVG : 215.921 sec, 8
# ---
# spark.rdd.compress : ---  false
# default_: 182.216 sec,  AVG true: 190.879 sec, 9
# spark.rdd.compress_true: 183.224 sec,  AVG : 215.921 sec, 8
# ---
# spark.reducer.maxSizeInFlight : ---  48m
# default_: 182.216 sec,  AVG 80m: 196.435 sec, 9
# spark.reducer.maxSizeInFlight_72m: 182.771 sec,  AVG 72m: 196.439 sec, 8
# spark.reducer.maxSizeInFlight_88m: 182.829 sec,  AVG 56m: 197.137 sec, 8
# spark.reducer.maxSizeInFlight_56m: 183.052 sec,  AVG 64m: 197.582 sec, 8
# spark.reducer.maxSizeInFlight_64m: 183.587 sec,  AVG 88m: 197.642 sec, 8
# spark.reducer.maxSizeInFlight_96m: 184.036 sec,  AVG 96m: 199.063 sec, 8
# spark.reducer.maxSizeInFlight_80m: 184.111 sec,  AVG : 215.921 sec, 8
# ---
# spark.rpc.message.maxSize : ---  128
# default_: 182.216 sec,  AVG 160: 189.468 sec, 9
# spark.rpc.message.maxSize_224: 182.374 sec,  AVG 224: 190.339 sec, 8
# spark.rpc.message.maxSize_160: 182.432 sec,  AVG 256: 190.662 sec, 8
# spark.rpc.message.maxSize_256: 182.929 sec,  AVG 192: 193.026 sec, 8
# spark.rpc.message.maxSize_192: 183.823 sec,  AVG : 215.921 sec, 8
# ---
# spark.shuffle.compress : ---  true
# spark.shuffle.compress_false: 169.909 sec,  AVG false: 186.234 sec, 8
# default_: 182.216 sec,  AVG : 215.921 sec, 9
# ---
# spark.shuffle.file.buffer : ---  32k
# default_: 182.216 sec,  AVG 48k: 202.157 sec, 9
# spark.shuffle.file.buffer_48k: 188.096 sec,  AVG 80k: 210.346 sec, 8
# spark.shuffle.file.buffer_64k: 192.435 sec,  AVG 96k: 212.07 sec, 8
# spark.shuffle.file.buffer_80k: 198.489 sec,  AVG : 215.921 sec, 8
# spark.shuffle.file.buffer_96k: 198.969 sec,  AVG 128k: 224.747 sec, 8
# spark.shuffle.file.buffer_112k: 208.072 sec,  AVG 112k: 239.76 sec, 8
# spark.shuffle.file.buffer_128k: 216.225 sec,  AVG 64k: 254.945 sec, 8
# ---
# spark.shuffle.spill.compress : ---  true
# spark.shuffle.spill.compress_false: 182.095 sec,  AVG false: 198.955 sec, 8
# default_: 182.216 sec,  AVG : 215.921 sec, 9
# ---
# spark.sql.shuffle.partitions : ---  100
# spark.sql.shuffle.partitions_80: 177.45 sec,  AVG 80: 184.869 sec, 8
# spark.sql.shuffle.partitions_70: 179.26 sec,  AVG 70: 186.582 sec, 8
# spark.sql.shuffle.partitions_90: 180.156 sec,  AVG 90: 186.962 sec, 8
# spark.sql.shuffle.partitions_60: 180.303 sec,  AVG 60: 188.248 sec, 8
# default_: 182.216 sec,  AVG 120: 192.263 sec, 9
# spark.sql.shuffle.partitions_120: 185.536 sec,  AVG 110: 192.535 sec, 8
# spark.sql.shuffle.partitions_110: 185.578 sec,  AVG 130: 194.289 sec, 8
# spark.sql.shuffle.partitions_130: 187.717 sec,  AVG 50: 195.136 sec, 8
# spark.sql.shuffle.partitions_50: 188.188 sec,  AVG 140: 199.861 sec, 8
# spark.sql.shuffle.partitions_140: 192.183 sec,  AVG : 215.921 sec, 8
# ---
# spark.task.cpus : ---  1
# default_: 182.216 sec,  AVG : 215.921 sec, 9
# ---
# ./training_results/sf10_n10_det_main_fix.txt
# spark.broadcast.blockSize : ---  4m
# spark.broadcast.blockSize_20m: 182.883 sec,  AVG 12m: 182.791 sec, 9
# spark.broadcast.blockSize_12m: 183.077 sec,  AVG 8m: 183.172 sec, 9
# spark.broadcast.blockSize_6m: 183.531 sec,  AVG 10m: 183.248 sec, 9
# spark.broadcast.blockSize_16m: 183.667 sec,  AVG 16m: 183.338 sec, 9
# spark.broadcast.blockSize_8m: 183.704 sec,  AVG 6m: 183.387 sec, 9
# spark.broadcast.blockSize_10m: 183.782 sec,  AVG 20m: 183.494 sec, 9
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# spark.broadcast.blockSize_22m: 184.017 sec,  AVG 18m: 184.038 sec, 9
# spark.broadcast.blockSize_18m: 184.762 sec,  AVG 22m: 184.307 sec, 9
# spark.broadcast.blockSize_14m: 185.262 sec,  AVG 14m: 184.643 sec, 9
# spark.broadcast.blockSize_24m: 185.524 sec,  AVG 24m: 184.852 sec, 9
# ---
# spark.broadcast.compress : ---  true
# spark.broadcast.compress_false: 182.335 sec,  AVG false: 182.446 sec, 9
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# ---
# spark.default.parallelism : ---  200
# spark.default.parallelism_60: 181.004 sec,  AVG 60: 180.672 sec, 10
# spark.default.parallelism_100: 181.732 sec,  AVG 100: 181.586 sec, 10
# spark.default.parallelism_140: 182.32 sec,  AVG 140: 182.297 sec, 10
# spark.default.parallelism_180: 182.732 sec,  AVG 180: 183.161 sec, 10
# spark.default.parallelism_220: 182.922 sec,  AVG 220: 183.318 sec, 10
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# spark.default.parallelism_260: 184.869 sec,  AVG 300: 186.905 sec, 10
# spark.default.parallelism_300: 185.064 sec,  AVG 260: 187.513 sec, 10
# spark.default.parallelism_380: 187.185 sec,  AVG 380: 189.233 sec, 10
# spark.default.parallelism_340: 187.989 sec,  AVG 340: 189.997 sec, 10
# ---
# spark.driver.cores : ---  1
# spark.driver.cores_4: 183.535 sec,  AVG 4: 182.69 sec, 9
# spark.driver.cores_2: 183.555 sec,  AVG 2: 183.281 sec, 9
# default_: 183.808 sec,  AVG 3: 183.529 sec, 10
# spark.driver.cores_3: 184.275 sec,  AVG : 183.948 sec, 9
# ---
# spark.driver.memory : ---  1g
# spark.driver.memory_4g: 120.163 sec,  AVG 4g: 120.389 sec, 9
# spark.driver.memory_3g: 122.034 sec,  AVG 3g: 122.574 sec, 9
# spark.driver.memory_2g: 138.434 sec,  AVG 2g: 137.966 sec, 9
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# ---
# spark.executor.cores : ---  1
# spark.executor.cores_5: 183.084 sec,  AVG 5: 183.051 sec, 10
# spark.executor.cores_2: 183.305 sec,  AVG 6: 183.179 sec, 10
# spark.executor.cores_8: 183.613 sec,  AVG 3: 183.39 sec, 10
# spark.executor.cores_6: 183.618 sec,  AVG 8: 183.668 sec, 10
# spark.executor.cores_3: 183.774 sec,  AVG 2: 183.697 sec, 10
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# spark.executor.cores_7: 184.111 sec,  AVG 4: 184.27 sec, 10
# spark.executor.cores_4: 184.287 sec,  AVG 7: 184.482 sec, 10
# ---
# spark.executor.instances : ---  2
# spark.executor.instances_6: 183.262 sec,  AVG 8: 183.464 sec, 9
# spark.executor.instances_5: 183.317 sec,  AVG 3: 183.523 sec, 9
# spark.executor.instances_3: 183.61 sec,  AVG 5: 183.822 sec, 9
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# spark.executor.instances_8: 183.825 sec,  AVG 4: 184.022 sec, 9
# spark.executor.instances_4: 184.021 sec,  AVG 7: 184.307 sec, 9
# spark.executor.instances_7: 184.743 sec,  AVG 6: 185.184 sec, 9
# ---
# spark.executor.memory : ---  1g
# spark.executor.memory_3g: 183.31 sec,  AVG 7g: 183.233 sec, 10
# spark.executor.memory_6g: 183.435 sec,  AVG 6g: 183.898 sec, 10
# default_: 183.808 sec,  AVG 3g: 183.915 sec, 10
# spark.executor.memory_7g: 183.86 sec,  AVG : 183.948 sec, 9
# spark.executor.memory_4g: 185.069 sec,  AVG 4g: 185.076 sec, 10
# spark.executor.memory_2g: 185.153 sec,  AVG 8g: 185.255 sec, 10
# spark.executor.memory_8g: 185.26 sec,  AVG 2g: 185.477 sec, 9
# spark.executor.memory_5g: 185.68 sec,  AVG 5g: 186.932 sec, 10
# ---
# spark.io.compression.codec : ---  lz4
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# spark.io.compression.codec_snappy: 185.61 sec,  AVG snappy: 187.19 sec, 9
# ---
# spark.memory.fraction : ---  0.6
# spark.memory.fraction_0.5: 183.621 sec,  AVG : 183.948 sec, 9
# default_: 183.808 sec,  AVG 0.5: 184.045 sec, 10
# spark.memory.fraction_0.4: 185.302 sec,  AVG 0.4: 185.035 sec, 9
# spark.memory.fraction_0.7: 187.468 sec,  AVG 0.7: 186.966 sec, 9
# spark.memory.fraction_0.3: 191.595 sec,  AVG 0.3: 191.667 sec, 9
# spark.memory.fraction_0.8: 193.006 sec,  AVG 0.8: 193.841 sec, 9
# ---
# spark.memory.storageFraction : ---  0.5
# spark.memory.storageFraction_0.7: 182.85 sec,  AVG 0.8: 183.053 sec, 9
# spark.memory.storageFraction_0.8: 183.261 sec,  AVG 0.7: 183.427 sec, 9
# spark.memory.storageFraction_0.4: 183.723 sec,  AVG : 183.948 sec, 9
# default_: 183.808 sec,  AVG 0.6: 184.043 sec, 10
# spark.memory.storageFraction_0.3: 184.473 sec,  AVG 0.4: 184.547 sec, 9
# spark.memory.storageFraction_0.6: 184.515 sec,  AVG 0.3: 184.607 sec, 9
# ---
# spark.rdd.compress : ---  false
# default_: 183.808 sec,  AVG true: 183.885 sec, 10
# spark.rdd.compress_true: 184.087 sec,  AVG : 183.948 sec, 9
# ---
# spark.reducer.maxSizeInFlight : ---  48m
# spark.reducer.maxSizeInFlight_72m: 180.893 sec,  AVG 72m: 181.537 sec, 9
# spark.reducer.maxSizeInFlight_64m: 182.012 sec,  AVG 80m: 182.429 sec, 9
# spark.reducer.maxSizeInFlight_80m: 182.592 sec,  AVG 56m: 182.575 sec, 9
# spark.reducer.maxSizeInFlight_56m: 183.054 sec,  AVG 64m: 182.723 sec, 9
# spark.reducer.maxSizeInFlight_88m: 183.121 sec,  AVG 96m: 183.121 sec, 9
# default_: 183.808 sec,  AVG 88m: 183.239 sec, 10
# spark.reducer.maxSizeInFlight_96m: 183.895 sec,  AVG : 183.948 sec, 9
# ---
# spark.rpc.message.maxSize : ---  128
# spark.rpc.message.maxSize_192: 181.872 sec,  AVG 192: 182.27 sec, 9
# spark.rpc.message.maxSize_160: 183.004 sec,  AVG 160: 183.031 sec, 9
# default_: 183.808 sec,  AVG 224: 183.385 sec, 10
# spark.rpc.message.maxSize_224: 184.407 sec,  AVG : 183.948 sec, 9
# spark.rpc.message.maxSize_256: 185.377 sec,  AVG 256: 184.61 sec, 9
# ---
# spark.shuffle.compress : ---  true
# spark.shuffle.compress_false: 171.7 sec,  AVG false: 170.662 sec, 9
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# ---
# spark.shuffle.file.buffer : ---  32k
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# spark.shuffle.file.buffer_48k: 186.061 sec,  AVG 48k: 188.2 sec, 9
# spark.shuffle.file.buffer_64k: 190.528 sec,  AVG 64k: 190.348 sec, 9
# spark.shuffle.file.buffer_80k: 195.379 sec,  AVG 80k: 195.518 sec, 9
# spark.shuffle.file.buffer_96k: 197.8 sec,  AVG 96k: 198.275 sec, 9
# spark.shuffle.file.buffer_112k: 203.282 sec,  AVG 112k: 204.003 sec, 9
# spark.shuffle.file.buffer_128k: 212.661 sec,  AVG 128k: 212.357 sec, 9
# ---
# spark.shuffle.spill.compress : ---  true
# spark.shuffle.spill.compress_false: 182.46 sec,  AVG false: 182.989 sec, 9
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# ---
# spark.sql.shuffle.partitions : ---  100
# spark.sql.shuffle.partitions_70: 176.412 sec,  AVG 80: 177.454 sec, 9
# spark.sql.shuffle.partitions_80: 177.32 sec,  AVG 70: 178.039 sec, 9
# spark.sql.shuffle.partitions_60: 179.549 sec,  AVG 60: 179.562 sec, 9
# spark.sql.shuffle.partitions_90: 180.527 sec,  AVG 90: 180.925 sec, 9
# spark.sql.shuffle.partitions_120: 183.468 sec,  AVG : 183.948 sec, 9
# default_: 183.808 sec,  AVG 120: 184.116 sec, 10
# spark.sql.shuffle.partitions_130: 186.106 sec,  AVG 110: 186.674 sec, 9
# spark.sql.shuffle.partitions_110: 186.772 sec,  AVG 130: 186.832 sec, 9
# spark.sql.shuffle.partitions_50: 187.886 sec,  AVG 50: 188.662 sec, 9
# spark.sql.shuffle.partitions_140: 192.595 sec,  AVG 140: 192.762 sec, 9
# ---
# spark.task.cpus : ---  1
# default_: 183.808 sec,  AVG : 183.948 sec, 10
# ---

# %%
# somewhat good result? -- handtuning sometimes selected the same parameters across both

#training_fnames
#pvals[FNAME][pname] = defa
print(training_fnames)
for pname in sorted(names):
    print(f"'{pname}': Median best val (job1) (job2)", pvals[training_fnames[0]][pname], pvals[training_fnames[1]][pname], "AVG best val", pvals["AVG_"+training_fnames[0]][pname], pvals["AVG_"+training_fnames[1]][pname])
# Out:
# ['./training_results/sf10_n10_det_main0.txt', './training_results/sf10_n10_det_main_fix.txt']
# 'spark.broadcast.blockSize': Median best val (job1) (job2) 4m 20m AVG best val 24m 12m
# 'spark.broadcast.compress': Median best val (job1) (job2) true false AVG best val false false
# 'spark.default.parallelism': Median best val (job1) (job2) 60 60 AVG best val 60 60
# 'spark.driver.cores': Median best val (job1) (job2) 1 4 AVG best val 4 4
# 'spark.driver.memory': Median best val (job1) (job2) 3g 4g AVG best val 4g 4g
# 'spark.executor.cores': Median best val (job1) (job2) 6 5 AVG best val 6 5
# 'spark.executor.instances': Median best val (job1) (job2) 6 6 AVG best val 8 8
# 'spark.executor.memory': Median best val (job1) (job2) 5g 3g AVG best val 1g 7g
# 'spark.io.compression.codec': Median best val (job1) (job2) lz4 lz4 AVG best val snappy lz4
# 'spark.memory.fraction': Median best val (job1) (job2) 0.5 0.5 AVG best val 0.5 0.6
# 'spark.memory.storageFraction': Median best val (job1) (job2) 0.5 0.7 AVG best val 0.8 0.8
# 'spark.rdd.compress': Median best val (job1) (job2) false false AVG best val true true
# 'spark.reducer.maxSizeInFlight': Median best val (job1) (job2) 48m 72m AVG best val 80m 72m
# 'spark.rpc.message.maxSize': Median best val (job1) (job2) 128 192 AVG best val 160 192
# 'spark.shuffle.compress': Median best val (job1) (job2) false false AVG best val false false
# 'spark.shuffle.file.buffer': Median best val (job1) (job2) 32k 32k AVG best val 48k 32k
# 'spark.shuffle.spill.compress': Median best val (job1) (job2) false false AVG best val false false
# 'spark.sql.shuffle.partitions': Median best val (job1) (job2) 80 70 AVG best val 80 80
# 'spark.task.cpus': Median best val (job1) (job2) 1 1 AVG best val 1 1

# %%
# handtuning result based on sf 10 results
hand_tuning10 = {
'spark.broadcast.blockSize':  '24m',
'spark.broadcast.compress':  'false',
'spark.default.parallelism':  '60',
'spark.driver.cores':  '3',
'spark.driver.memory':  '4g',
'spark.executor.cores':  '3',
'spark.executor.instances':  '8',
'spark.executor.memory':  '7g',
'spark.io.compression.codec':  'snappy',
'spark.memory.fraction':  '0.5',
'spark.memory.storageFraction':  '0.6',
'spark.rdd.compress':  'true', 
'spark.reducer.maxSizeInFlight':  '72m',
'spark.rpc.message.maxSize': '224',
'spark.shuffle.compress':  'false',
'spark.shuffle.file.buffer':  '32k',
'spark.shuffle.spill.compress':  'false', 
'spark.sql.shuffle.partitions':  '80',
'spark.task.cpus':  '1',  
}

# %%
# based on sf 1 results
hand_tuning = {
'spark.broadcast.blockSize':  '14m',
'spark.broadcast.compress':  'false',
'spark.default.parallelism':  '20',
'spark.driver.cores':  '3',
'spark.driver.memory':  '4g',
'spark.executor.cores':  '8',
'spark.executor.instances':  '8',
'spark.executor.memory':  '4g',
'spark.io.compression.codec':  'snappy',
'spark.memory.fraction':  '0.8',
'spark.memory.storageFraction':  '0.7',
'spark.rdd.compress':  'true', 
'spark.reducer.maxSizeInFlight':  '80m',
'spark.rpc.message.maxSize': '192',
'spark.shuffle.compress':  'false',
'spark.shuffle.file.buffer':  '48k',
'spark.shuffle.spill.compress':  'false', 
'spark.sql.shuffle.partitions':  '50',
'spark.task.cpus':  '1',  
}

# %%
# combine deterministic and random parameter runtimes into a single json file that can be input into the other models
fnames = ['sf10_n10_det_main0.txt', 'sf10_n10_det_main_fix.txt']#
#['sf1_n10_det_main2.txt', 'sf1_n10_det_main.txt']
direc = './training_results'
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if x in fnames]
param_vals = {} #fname -> param_val -> list of times
names = []
params = []
for FNAME in training_fnames:
    print(FNAME)
    with open(FNAME, "r") as file:
        for line in file:
            d = eval(line)

            params = [p for p in d["params"] if p['spark_param']]
            names = [p['name'] for p in d["params"] if p['spark_param']]
            runtimes = d["runtimes"]
            
            varying_param = 'default'
            varying_val = ''
            for p in params:
                if str(p['cur_value']) != str(p['default_value']):
                    varying_param = p['name']
                    varying_val = p['cur_value']
                    break
                    
            if len(runtimes) == 0:
                param_vals.setdefault(f'{varying_param}_{varying_val}',[[],d])
                continue
                
            param_vals.setdefault(f'{varying_param}_{varying_val}',[[],d])[0].append(runtimes['total'])
           
count = 0
result = {}
valid = 0

for times, d in param_vals.values():
    if len(times) > 0:
        before = d['runtimes']['total']
        d['runtimes']['total'] = np.median(times) 
        valid += 1
        #print(before, d['runtimes']['total'])
    result[count] = d
    count += 1
print(count)
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'sf10_n1_rand' in x]
for fname in training_fnames:
    with open(fname, "r") as training_data:
        for line in training_data:
            result[count] = eval(line)
            if result[count]['runtimes']:
                valid += 1
            count +=1

# Writing to sample.json
with open(f"{direc}/sf10_training_data.json", "w") as outfile:
    json.dump(result, outfile)
f = open(f"{direc}/sf10_training_data.txt", "r")
x = f.readlines()
print(len(x), sum(1 if eval(t)['runtimes'] else 0 for t in x))
print("count" , count, '# valid', valid)
f.close()
# Out:
# ./training_results/sf10_n10_det_main0.txt
# ./training_results/sf10_n10_det_main_fix.txt
# 88
# 2882 2625
# count 3145 # valid 2865

# %%
# find overall lowest runtime parameter set -- lottery tuning
min_rt = float("inf")
best_p = {}
for d in result.values():
    if d['runtimes'] and d['runtimes']['total'] < min_rt:
        best_p = d['params']
        min_rt = d['runtimes']['total']
default_p = {p['name']: str(p['default_value']) for p in best_p if p['spark_param']}
best_p = {p['name']: p['cur_value'] for p in best_p if p['spark_param']}
#print(default_p)
print({k:v for k,v in sorted(best_p.items())})
# Out:
# {'spark.broadcast.blockSize': '6m', 'spark.broadcast.compress': 'false', 'spark.default.parallelism': 60, 'spark.driver.cores': 3, 'spark.driver.memory': '4g', 'spark.executor.cores': 3, 'spark.executor.instances': 7, 'spark.executor.memory': '1g', 'spark.io.compression.codec': 'snappy', 'spark.memory.fraction': 0.6, 'spark.memory.storageFraction': 0.4, 'spark.rdd.compress': 'true', 'spark.reducer.maxSizeInFlight': '64m', 'spark.rpc.message.maxSize': '192', 'spark.shuffle.compress': 'true', 'spark.shuffle.file.buffer': '96k', 'spark.shuffle.spill.compress': 'true', 'spark.sql.shuffle.partitions': 60, 'spark.task.cpus': 1}

# %%
# pretty print the parameter sets for the paper
from tpch_param import *
param_lists = get_param_lists()
raw_param_lists = [{p['name']:p['cur_value'] for p in pl} for pl in param_lists]
deft = raw_param_lists[0]
'''
for ps in raw_param_lists:
    print("----")
    print(str(tuple(v for  _, v in sorted(ps.items()))).replace("'",""))

print(str(tuple(sorted(ps))).replace("'",''))
'''
# Out:
# '\nfor ps in raw_param_lists:\n    print("----")\n    print(str(tuple(v for  _, v in sorted(ps.items()))).replace("\'",""))\n\nprint(str(tuple(sorted(ps))).replace("\'",\'\'))\n'

# %%
# comparing results of chosen parameter sets 

direc = './training_results'
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'compare_all' in x]
#direc = '../../../../nobackup1/hoped/spark-autotuner/training_data/training_results'

param_vals = [tuple(str(v) for _,v in sorted(pl.items())) for pl in raw_param_lists]
param_names = {param_vals[0]: 'default', param_vals[1]: 'hand_tuning1', param_vals[2]: 'hand_tuning2', param_vals[3]: 'lottery',}
param_names.update({param_vals[i+4]: f"markov{i+1}" for i in range(6)})
param_names.update({param_vals[-5:][i]: f"random_forest{i+1}" for i in range(5)})
print(len(param_vals))
print(len(param_names), param_names.values())

len(training_fnames)
print(training_fnames)
for FNAME in  training_fnames:
    import json
    import os
    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    
    with open(FNAME,'r') as file:
        try:
            file_data = file.readlines()
        except Exception as e:
            print(FNAME, "load error")
            print(e)
            continue
    if len(file_data) < 5:
        continue

    class Parameter:
        def __init__(self, name):
            self.name = name
            self.val_to_results = []

        def add(self, results):
            self.val_to_results.append(results)

    param_name_to_param_obj = {}

    def populate_params():
        #analyze one file

        with open(FNAME, "r") as file:
            for line in file:
                d = eval(line)
       
                params = [(p['name'], p['cur_value']) for p in d["params"] if p['spark_param']]
                vals = tuple(str(v) for _,v in sorted(params))
                if vals not in param_names:
                    print(vals, "!!!")
                    continue
                name = param_names[vals]
                runtimes = d["runtimes"]
                if len(runtimes) == 0:
                    print("no times?")
                    continue

                if name not in param_name_to_param_obj:
                    param_name_to_param_obj[name] = Parameter(name)
                obj = param_name_to_param_obj[name]
                assert "total" in runtimes
                obj.add(runtimes)

    def analyze_results():
        populate_params()
        timess = []
        names = []
 
        for p in param_name_to_param_obj:
            min_runtime = float("inf")
            max_runtime = -float("inf")
            times = []
            obj = param_name_to_param_obj[p]
            for d in obj.val_to_results:
                total_time = d['total']
                times.append(total_time)
  
            timess.append(times)
            names.append(f'{p} (N {len(times)})')
            #names.append(p)

      
        name = FNAME.split('/')[-1].split('.')[0]
        print(name)
        data = timess
        fig = plt.figure(figsize =(10, 5))

        # Creating axes instance
        ax = fig.add_axes([0, 0, 1, 1])

        # Creating plot
        bp = ax.boxplot(data)

        ax.set_xticklabels(names)
        plt.xticks(rotation=90)
        plt.title(f"Parameter Set Runtimes")
        plt.xlabel("Parameter Set Name")
        plt.ylabel("Times (s)")
        plt.savefig(f"./training_sensitivity/compare_boxplots{name}.jpg", bbox_inches="tight")
        plt.title(f"Parameter Set Runtimes TPC-H SF10")
        plt.show()

    analyze_results()
    
# run it locally
# check number of rows that are loading
# look at and verify result to materialize the answer
# Out:
# 15
# 15 dict_values(['default', 'hand_tuning1', 'hand_tuning2', 'lottery', 'markov1', 'markov2', 'markov3', 'markov4', 'markov5', 'markov6', 'random_forest1', 'random_forest2', 'random_forest3', 'random_forest4', 'random_forest5'])
# ['./training_results/sf10_n10_compare_all_main7.txt', './training_results/sf10_n10_compare_all_main5.txt', './training_results/sf10_n10_compare_all_main4.txt', './training_results/sf10_n10_compare_all_main3.txt', './training_results/sf10_n10_compare_all_main2.txt', './training_results/sf10_n10_compare_all_main1.txt', './training_results/sf10_n10_compare_all_main8.txt']
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# sf10_n10_compare_all_main7
# sf10_n10_compare_all_main5
# sf10_n10_compare_all_main4
# sf10_n10_compare_all_main3
# sf10_n10_compare_all_main2
# sf10_n10_compare_all_main1
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# ('6m', 'false', '260', '3', '4g', '7', '5', '7g', 'snappy', '0.7', '0.6', 'false', '80m', '256', 'true', '32k', 'false', '80', '1') !!!
# ('6m', 'true', '180', '4', '4g', '1', '2', '4g', 'snappy', '0.4', '0.4', 'true', '80m', '256', 'false', '112k', 'false', '70', '1') !!!
# ('12m', 'false', '380', '1', '4g', '4', '6', '4g', 'snappy', '0.7', '0.7', 'false', '72m', '224', 'false', '80k', 'false', '90', '1') !!!
# ('4m', 'false', '140', '1', '4g', '5', '6', '3g', 'lz4', '0.6', '0.6', 'false', '80m', '160', 'false', '64k', 'false', '120', '1') !!!
# ('18m', 'false', '260', '4', '4g', '4', '5', '3g', 'snappy', '0.8', '0.7', 'true', '96m', '192', 'false', '48k', 'true', '80', '1') !!!
# sf10_n10_compare_all_main8

# %%
# How many tuned parameter sets are found in train data?
# How many params outperformed default?
def tuplify_vals(pdl):
    return tuple(str(v) for _,v in sorted([(x['name'], x['cur_value']) for x in pdl if x['spark_param']]) )
with open(f"{direc}/sf10_training_data.json", "r") as outfile:
    result = json.load(outfile)
f = open(f"{direc}/sf10_training_data.txt", "r")
result_txt = f.readlines()
result_txt = [eval(x) for x in result_txt]
f.close()

raw_result = {}
for d in result.values():
    k = tuplify_vals(d['params'])
    raw_result.setdefault(k, [])
    if d['runtimes']:
        raw_result[k].append(d['runtimes']['total'])

def_tup = tuple(str(v) for _,v in sorted(deft.items()))

raw_resulttxt = {}
for d in result_txt:
    k = tuplify_vals(d['params'])
    raw_resulttxt.setdefault(k, [])
    if d['runtimes']:
        raw_resulttxt[k].append(d['runtimes']['total'])
    

print("Num unique params:", len(raw_result), len(raw_resulttxt))
print("How many tuned parameter sets are found in train data?")
select_repeats = [param_names[k] for k in param_names if k in raw_result]
select_repeatstxt = [param_names[k] for k in param_names if k in raw_resulttxt]
print(len(select_repeats), select_repeats)
print(len(select_repeatstxt), select_repeatstxt)
# Out:
# Num unique params: 3145 2882
# How many tuned parameter sets are found in train data?
# 2 ['default', 'lottery']
# 2 ['default', 'lottery']

# %%
# How many params outperformed the default?
c = 0
all_times = []
def_med = min(raw_result[def_tup])
for times in raw_result.values():
    
    if times and np.median(times) < def_med:
        c += 1

ct = 0
def_med = np.median(raw_resulttxt[def_tup])
for times in raw_resulttxt.values():
    all_times.extend(times)
    if times and np.median(times) < def_med:
        ct += 1
print("How many params outperformed the default?", c, ct)

data = [all_times]
fig = plt.figure(figsize =(5, 5))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot(data)

percentiles = [np.percentile(all_times, i) for i in range(0, 101, 25)]
nms = ['Min', 'Q1', 'Overall Median', 'Q3', 'Q4']
print(percentiles)
for i in range(len(nms)):
    plt.annotate(f'{nms[i]} {round(percentiles[i])} s', (1.1, percentiles[i]))
    
#ax.set_xticklabels(names)
plt.axline((0, def_med), (2, def_med) , linestyle='--')
plt.annotate(f'Default median {round(def_med)} s', (.1, def_med+10))
plt.xticks(rotation=90)
#plt.xlabel("Parameter Set Name")
plt.ylabel("Times (s)")
plt.title(f"All Valid Paramater Runtimes TPC-H SF10 (N {len(all_times)})")
plt.savefig(f"./training_sensitivity/all_runtimes.jpg", bbox_inches="tight")
plt.show()
# Out:
# How many params outperformed the default? 1106 1076
# [111.53646945953369, 152.56019234657288, 192.52007675170898, 258.17023038864136, 1206.5933125019073]

# %%
direc = './training_results'
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'sf10' in x and 'det' in x]
#direc = '../../../../nobackup1/hoped/spark-autotuner/training_data/training_results'

len(training_fnames)
print(training_fnames)
for FNAME in  training_fnames:
    import json
    import os
    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    
    with open(FNAME,'r') as file:
        try:
            file_data = file.readlines()
        except Exception as e:
            print(FNAME, "load error")
            print(e)
            continue
    if len(file_data) < 5:
        continue

    class Parameter:
        def __init__(self, name):
            self.name = name
            self.val_to_results = {}

        def add(self, param_val, results):
            self.val_to_results.setdefault(param_val, []).append(results['total'])

        def get_totals(self, param_val):
            return self.val_to_results[param_val]

        def get_param_vals(self):
            return set(self.val_to_results.keys())

    param_name_to_param_obj = {}

    def populate_params():
        #analyze one file
        
        with open(FNAME, "r") as file:
            for line in file:
                d = eval(line)
       
                params = [p for p in d["params"] if p['spark_param']]
                runtimes = d["runtimes"]
                if len(runtimes) == 0:
                    continue

                all_default = True
                for p in params:
                    if str(p['cur_value']) != str(p['default_value']):
                        varying_param = p['name']
                        all_default = False
                        break
                if all_default:
                    if 'default' not in param_name_to_param_obj:
                        param_name_to_param_obj["default"] = Parameter('default')

                    obj = param_name_to_param_obj["default"]
                    obj.add("default", runtimes)
                    continue

                if varying_param not in param_name_to_param_obj:
                    param_name_to_param_obj[varying_param] = Parameter(varying_param)
                obj = param_name_to_param_obj[varying_param]
                assert "total" in runtimes
                obj.add(p['cur_value'], runtimes)

    def analyze_results():
        populate_params()
        pnum = {}
        default = param_name_to_param_obj["default"]
        default_total = default.get_totals("default")
        names = ['default']
        data = [default_total]
        med_data = []
        med_names = []
        count = len(default_total)
        for p in sorted(param_name_to_param_obj):
            if p == 'default':
                 continue

            
            obj = param_name_to_param_obj[p]
            pnum[p] = len(obj.val_to_results)
            all_times = []
            for k in obj.get_param_vals():
                all_times.extend(obj.get_totals(k))
            count += len(all_times)
            names.append(f'{p}')
            data.append(all_times)
            for k in sorted(obj.get_param_vals()):
                med_names.append(f'{p}_{k}')
                med_data.append(obj.get_totals(k))
                

        name = FNAME.split('/')[-1].split('.')[0]
        print(name)
        fig = plt.figure(figsize =(10, 5))

        # Creating axes instance
        ax = fig.add_axes([0, 0, 1, 1])

        # Creating plot
        bp = ax.boxplot(data)

        ax.set_xticklabels([f'{i} {n}' for i,n in enumerate(names)])
        plt.xticks(rotation=90)
        plt.title(f"Deterministic Parameter Set Runtimes TPC-H SF10 (N {count})")
        plt.xlabel("Parameter Set Name")
        plt.ylabel("Times (s)")
        plt.savefig(f"./training_sensitivity/det_boxplots{name}.jpg", bbox_inches="tight")
       
        plt.show()
        
        
        figure, axis = plt.subplots(2, 1, figsize=(10, 5))


        # Creating errorbars 
        x1 = [0]
        y1 = [np.average(default_total)]
        e1 = [np.std(default_total)]
        x2, y2, e2 = [0], [np.average(default_total)], [np.std(default_total)]
        prev_p = ''
        n = 0
        t1 = set([0])
        t2 = set([0])
        besta1 = [np.average(default_total)]
        bestk1 = ['def']
        besta2 = [np.average(default_total)]
        bestk2 = ['def']
        for i in range(len(med_names)):
            p, k = med_names[i].split("_")
            if prev_p!=p:
                prev_p = p
                n = 0
            else:
                n += 1.7/(pnum[p])
            yv = 0 if not med_data[i] else np.average(med_data[i])
            ev = 0 if not med_data[i] else np.std(med_data[i])
            xv = 3*names.index(p) + n -1
            if pnum[p] == 1:
                    xv += .5
            if (names.index(p) < len(names)/2):
                x1.append(xv)
                y1.append(yv)
                e1.append(ev)
                t1.add(3*names.index(p)-.5)
                if n == 0:
                    besta1.append(float('inf') if not med_data[i] else np.average(med_data[i]))
                    bestk1.append(k)
                else:
                    bestk1[-1] = k if yv < besta1[-1] else bestk1[-1]
                    besta1[-1] = yv if yv < besta1[-1] else besta1[-1]
            else:
                xv -= 3*len(names)//2-1
                x2.append(xv)
                y2.append(yv)
                e2.append(ev)
                t2.add(3*names.index(p)-1)
                if n == 0:
                    besta2.append(float('inf') if not med_data[i] else np.average(med_data[i]))
                    bestk2.append(k)
                else:
                    bestk2[-1] = k if yv < besta2[-1] else bestk2[-1]
                    besta2[-1] = yv if yv < besta2[-1] else besta2[-1]

        xs1 = list(sorted(t1))
        
        axis[1].scatter(xs1, besta2, color='red', zorder=10)
        axis[0].scatter(xs1, besta1, color='red', zorder=10)
        axis[0].errorbar(x1, y1, e1, fmt='o', capsize=10)
        axis[1].errorbar(x2, y2, e2, fmt='o', capsize=10)
        #plt.annotate(f'Default median {round(def_med)} s', (-1, def_med+10))

        
        
        axis[0].set_xticks(xs1)
        axis[0].set_xticklabels([0]+[i+1 for i in range(len(t1)-1)])
        axis[1].set_xticks(xs1)
        axis[1].set_xticklabels([0]+[i+len(t1) for i in range(len(t2)-1)])
        axis[0].set_title(f"Deterministic Parameter Set Runtimes TPC-H SF10 (N {count})")
        axis[1].set_xlabel("Parameter Set Name")
        axis[0].set_ylabel("Times (s)")
        #plt.savefig(f"./training_sensitivity/det_errors_{name}.jpg", bbox_inches="tight")
       
        plt.show()

    analyze_results()
# Out:
# ['./training_results/sf10_n10_det_main0.txt', './training_results/sf10_n10_det_main_fix.txt']
# sf10_n10_det_main0
# sf10_n10_det_main_fix
