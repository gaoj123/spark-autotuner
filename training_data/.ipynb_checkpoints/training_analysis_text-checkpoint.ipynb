# %%
import os 
import sys 
import time 
import numpy as np
import json
import tpch_param as tp

# %%
DET_PARAMS_FNAME = "./training_params/detparams_n10.json"
DET_PARAMS = None
with open(DET_PARAMS_FNAME, 'rb') as f:
    DET_PARAMS = json.load(f)
    print(len(DET_PARAMS))

training_fnames = ['./training_results/'+x for x in os.listdir('./training_results') if 'txt' in x and 'det_main' in x]
len(training_fnames)
print(training_fnames)

def get_spark_params(result_dict):
    param_vals = []
    for param in tp.SPARK_PARAMETERS:
        for p in result_dict['params']:
            if p['name'] == param['name']:
                param_vals.append(p['cur_value'])
    return tuple(param_vals)
# Out:
# 880
# ['./training_results/sf1_n1_det_main2.txt', './training_results/sf1_n5_det_main2.txt', './training_results/sf1_n10_det_main2.txt', './training_results/sf1_n10_det_main.txt', './training_results/sf10_n10_det_main_fix.txt']

# %%
defaults = tuple(a['default_value'] for a in tp.SPARK_PARAMETERS)
defaults
# Out:
# (1,
#  '1g',
#  2,
#  1,
#  '1g',
#  '48m',
#  'true',
#  'true',
#  '32k',
#  '4m',
#  'true',
#  0.6,
#  '128',
#  'false',
#  'lz4',
#  1,
#  100,
#  200,
#  0.5)

# %%
fname_numdata = {}
fname_numdet = {}
deterministic_data = {}

for fname in training_fnames:
    with open(fname,'r') as file:
        lines = file.readlines()
        fname_numdata[fname] = len(lines)
        deterministic_data[fname] = {}
        
        for k in DET_PARAMS:
            if int(k) < len(lines):
                deterministic_data[fname][k] = eval(lines[int(k)])
        fname_numdet[fname] = len(deterministic_data[fname])
        if fname_numdet[fname] < 5:
            del fname_numdet[fname]
            del deterministic_data[fname]
            
print(sum(fname_numdata.values()))
print(fname_numdata)
print(fname_numdet)
# Out:
# 1268
# {'./training_results/sf1_n1_det_main2.txt': 50, './training_results/sf1_n5_det_main2.txt': 50, './training_results/sf1_n10_det_main2.txt': 762, './training_results/sf1_n10_det_main.txt': 396, './training_results/sf10_n10_det_main_fix.txt': 10}
# {'./training_results/sf1_n1_det_main2.txt': 50, './training_results/sf1_n5_det_main2.txt': 50, './training_results/sf1_n10_det_main2.txt': 762, './training_results/sf1_n10_det_main.txt': 396, './training_results/sf10_n10_det_main_fix.txt': 10}

# %%
det_params = {}
det_rt = {}
for fname, data in deterministic_data.items():
    det_params[fname] = []
    det_rt[fname] = []
    for result_dict in data.values():
        det_params[fname].append(get_spark_params(result_dict))
        if result_dict['runtimes']:
            det_rt[fname].append(result_dict['runtimes']['total']) # total
    if not det_params[fname]:
        print(fname)
        del det_params[fname]
        del det_rt[fname]
prev_fname = fname
for fname in det_params:
    assert 'det' not in fname or det_params[fname][0] == defaults, f'{det_params[fname][0]} !=\n{defaults}'
    #assert str(det_params[fname]) == str(det_params[prev_fname]), fname + " " + prev_fname
    print(fname, '\n',det_rt[fname][0], det_rt[fname][-1], max(det_rt[fname]), min(det_rt[fname]), len(det_rt[fname]))
# Out:
# ./training_results/sf1_n1_det_main2.txt
#  386.0415635108948 602.0818426609039 602.0818426609039 276.11343145370483 50
# ./training_results/sf1_n5_det_main2.txt
#  382.4356498718262 562.2691829204559 562.2691829204559 271.5381712913513 50
# ./training_results/sf1_n10_det_main2.txt
#  123.33979225158691 43.444156646728516 232.55123138427734 38.39085578918457 754
# ./training_results/sf1_n10_det_main.txt
#  91.26099371910095 43.632628202438354 111.05257844924927 37.64832139015198 392
# ./training_results/sf10_n10_det_main_fix.txt
#  191.07653999328613 187.37406635284424 191.07653999328613 182.58290481567383 10

# %%
# how many different param combos have we tried?
fname_num_params = {}
fname_valid = {}
for fname in training_fnames:
    with open(fname,'r') as file:
        lines = file.readlines()
        fname_num_params[fname] = set()
        fname_valid[fname] = 0
        for result_dict in lines:
            result_dict = eval(result_dict)
            fname_num_params[fname].add(get_spark_params(result_dict))
            fname_valid[fname] += 1 if result_dict['runtimes'] else 0

# %%
print(sum([len(x) for x in fname_num_params.values()]))
for fname, vals in fname_num_params.items():
    print(fname[18:60], '\nnum unique params', len(vals), 'total runs',fname_numdata[fname] , 'valid runs', fname_valid[fname])
# Out:
# 286
# /sf1_n1_det_main2.txt
# num unique params 50 total runs 50 valid runs 50
# /sf1_n5_det_main2.txt
# num unique params 50 total runs 50 valid runs 50
# /sf1_n10_det_main2.txt
# num unique params 88 total runs 762 valid runs 755
# /sf1_n10_det_main.txt
# num unique params 88 total runs 396 valid runs 393
# /sf10_n10_det_main_fix.txt
# num unique params 10 total runs 10 valid runs 10

# %%
#det_rt

# %%
for fname in det_rt:
    all_runs = []
    runs = []
    for run in det_rt[fname]:
        all_runs.append(run)
        runs.append(run)
    print(fname, 'avg ', round(np.average(runs), 5), 'median', round(np.median(runs), 5), 'range ', round(max(runs)-min(runs),5), 'std ', round(np.std(runs), 5))
print('overall runs avg ', round(np.average(all_runs), 5), 'median', round(np.median(all_runs), 5), 'range ', round(max(all_runs)-min(all_runs),5), 'std ', round(np.std(all_runs), 5))
# Out:
# ./training_results/sf1_n1_det_main2.txt avg  381.22656 median 379.1603 range  325.96841 std  64.28443
# ./training_results/sf1_n5_det_main2.txt avg  375.89037 median 367.59325 range  290.73101 std  66.90491
# ./training_results/sf1_n10_det_main2.txt avg  62.147 median 50.02762 range  194.16038 std  28.88511
# ./training_results/sf1_n10_det_main.txt avg  83.17725 median 86.46206 range  73.40426 std  13.80224
# ./training_results/sf10_n10_det_main_fix.txt avg  185.2729 median 184.40833 range  8.49364 std  2.60167
# overall runs avg  185.2729 median 184.40833 range  8.49364 std  2.60167

# %%
#training_fnames = ['./training_results/'+x for x in os.listdir('./training_results') if 'json' in x and 'test_clear_ports' in x]
#direc = '../../../../nobackup1/hoped/spark-autotuner/training_data/training_results'
#training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'json' in x and 'nobackup_deterministic_raw_runtimes' in x]
direc = './training_results'
print (os.listdir(direc), "\n")
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'det_main' in x]
#direc = '../../../../nobackup1/hoped/spark-autotuner/training_data/training_results'

len(training_fnames)
print(training_fnames)
for FNAME in  training_fnames:
    import json
    import os
    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    
    with open(FNAME,'r') as file:
        try:
            file_data = file.readlines()
        except Exception as e:
            print(FNAME, "load error")
            print(e)
            continue
    if len(file_data) < 5:
        continue

    class Parameter:
        def __init__(self, name):
            self.name = name
            self.val_to_results = {}

        def add(self, param_val, results):
            self.val_to_results[param_val] = results

        def get_total(self, param_val):
            if param_val in self.val_to_results:
                return self.val_to_results[param_val]["total"] # change

        def get_param_vals(self):
            return set(self.val_to_results.keys())

    param_name_to_param_obj = {}

    def populate_params():
        #analyze one file

        with open(FNAME, "r") as file:
            for line in file:
                d = eval(line)
       
                params = [p for p in d["params"] if p['spark_param']]
                runtimes = d["runtimes"]
                if len(runtimes) == 0:
                    continue

                all_default = True
                for p in params:
                    if str(p['cur_value']) != str(p['default_value']):
                        varying_param = p['name']
                        all_default = False
                        break
                if all_default:
                    if 'default' not in param_name_to_param_obj:
                        param_name_to_param_obj["default"] = Parameter('default')

                    obj = param_name_to_param_obj["default"]
                    obj.add(len(obj.val_to_results), runtimes)
                    continue

                if varying_param not in param_name_to_param_obj:
                    param_name_to_param_obj[varying_param] = Parameter(varying_param)
                obj = param_name_to_param_obj[varying_param]
                assert "total" in runtimes
                obj.add(p['cur_value'], runtimes)

    def analyze_results():
        populate_params()
        default = param_name_to_param_obj["default"]
        default_total = [default.get_total(k) for k in default.get_param_vals()]
        print('deftotal',default_total)
        mins = []
        names = []
        diffs = []
        stds = []
        for p in sorted(param_name_to_param_obj):
            min_runtime = float("inf")
            max_runtime = -float("inf")
            times = []
            if p != 'default':
                obj = param_name_to_param_obj[p]
                for k in obj.get_param_vals():
                    total_time = obj.get_total(k)
                    if type(total_time) == list:
                        times.extend(total_time)
                        min_runtime = min(min_runtime, min(total_time))
                        max_runtime = max(max_runtime, max(total_time))
                    else:
                        times.append(total_time)
                        min_runtime = min(min_runtime, total_time)
                        max_runtime = max(max_runtime, total_time)
                if min_runtime == max_runtime:
                    max_runtime += .01


            else:
                times.extend(default_total)
                min_runtime = min(default_total)
                max_runtime = max(default_total)
            stds.append(np.std(times))
            if p == 'default':
                print(f"{p}, min: {round(min_runtime,5)}, max: {round(max_runtime,5)}, median {round(np.median(times),5)}, avg: {round(np.average(times),5)}  default: {round(min(default_total),5), round(max(default_total),5)}")
            mins.append(min_runtime)
            diffs.append(max_runtime - min_runtime)
            names.append(p)

        #save total time std to csv
        df = pd.DataFrame(list(zip(names, stds)),
        columns =['name', 'standard_dev_total_times'])
        df.to_csv("./training_sensitivity/all_runtime_stds.csv", mode='w')

        #plot std
        fig = plt.figure(figsize = (10, 5))
        plt.xticks(rotation=90)
        plt.bar(names, stds, bottom=[0]*len(names), width=0.2)
        plt.title("Standard deviation of total query times for each parameter")
        plt.xlabel("Parameter")
        plt.ylabel("Standard deviation of times")
        name = FNAME.split("/")[-1][:-4]
        print(name, len(file_data))
        plt.savefig(f"./training_sensitivity/all_runtime_stds{name}.jpg", bbox_inches="tight")
        plt.show()

        #plot min/max times for each parameter
        fig = plt.figure(figsize = (10, 5))
        plt.xticks(rotation=90)
        plt.bar(names, diffs, bottom=mins, width=0.2)
        plt.title("Range of total query times for each parameter")
        plt.xlabel("Parameter")
        plt.ylabel("Range of times")
        plt.savefig(f"./training_sensitivity/all_runtime_ranges{name}.jpg", bbox_inches="tight")
        plt.show()

    analyze_results()
    
# run it locally
# check number of rows that are loading
# look at and verify result to materialize the answer
# Out:
# ['sf1_n10_det_alocal_test.txt', '.ipynb_checkpoints', 'sf10_n1_det_test.txt', 'sf1_n1_det_main2.txt', 'sf1_n5_det_main2.txt', 'sf1_n10_det_main2.txt', 'sf1_n1_rand_test.txt', 'sf10_n1_rand_test.txt', 'sf1_n1_det_test.txt', 'sf1_n1_det_test1.txt', 'sf1_n1_det_test2.txt', 'sf1_n1_det_test3.txt', 'sf1_n10_det_main.txt', 'sf1_n1_rand_main4.txt', 'sf1_n1_rand_main5.txt', 'sf1_n1_rand_main1.txt', 'sf1_n1_rand_main3.txt', 'sf1_n1_rand_main2.txt', 'sf10_n10_det_main_fix.txt', 'sf10_n1_rand_main_fix.txt']
#
# ['./training_results/sf1_n1_det_main2.txt', './training_results/sf1_n5_det_main2.txt', './training_results/sf1_n10_det_main2.txt', './training_results/sf1_n10_det_main.txt', './training_results/sf10_n10_det_main_fix.txt']
# deftotal [386.0415635108948]
# default, min: 386.04156, max: 386.04156, median 386.04156, avg: 386.04156  default: (386.04156, 386.04156)
# sf1_n1_det_main2 50
# deftotal [382.4356498718262]
# default, min: 382.43565, max: 382.43565, median 382.43565, avg: 382.43565  default: (382.43565, 382.43565)
# sf1_n5_det_main2 50
# deftotal [123.33979225158691, 140.57317280769348, 50.346794843673706, 50.17508149147034, 49.330902099609375, 49.20719623565674, 50.940053939819336, 50.42170023918152, 49.633732318878174]
# default, min: 49.2072, max: 140.57317, median 50.34679, avg: 68.21871  default: (49.2072, 140.57317)
# sf1_n10_det_main2 771
# deftotal [91.26099371910095, 85.19530129432678, 84.05660152435303, 87.09424328804016, 91.69003963470459]
# default, min: 84.0566, max: 91.69004, median 87.09424, avg: 87.85944  default: (84.0566, 91.69004)
# sf1_n10_det_main 404
# deftotal [191.07653999328613]
# default, min: 191.07654, max: 191.07654, median 191.07654, avg: 191.07654  default: (191.07654, 191.07654)
# sf10_n10_det_main_fix 12

# %%
#direc = '../../../../nobackup1/hoped/spark-autotuner/training_data/training_results'
#training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'rand' in x]
direc = './training_results'
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'sf324_n250_rand' in x]
len(training_fnames)
print(training_fnames)

fname_numdata = {'all':0}

for fname in training_fnames:
    with open(fname,'r') as file:
        try:
            file_data = file.readlines()
            fname_numdata[fname] = len(file_data)
            fname_numdata['all'] += len(file_data)
        except:
            print("error loading", fname)
print(sum(fname_numdata.values()))

# how many different param combos have we tried?
fname_num_params = {'all':set()}
fname_valid = {'all':0}
for fname in training_fnames:
    with open(fname,'r') as file:
        try:
            file_data = file.readlines()
        except:
            print("error loading", fname)
            continue
        fname_num_params[fname] = set()
        fname_valid[fname] = 0
        for result_dict in file_data:
            result_dict = eval(result_dict)
            fname_num_params[fname].add(get_spark_params(result_dict))
            fname_valid[fname] += 1 if result_dict['runtimes'] else 0
            fname_num_params['all'].add(get_spark_params(result_dict))
            fname_valid['all'] += 1 if result_dict['runtimes'] else 0
print(sum([len(x) for x in fname_num_params.values()]))
for fname, vals in fname_num_params.items():
    if fname == 'all':
        print("all:")

    print(fname, '\nnum unique params', len(vals), 'total runs',fname_numdata[fname] , 'valid runs', fname_valid[fname])

# %%
# hand tuning = pick the lowest time for each param after one deterministic run

# %%
fnames = ['sf1_n10_det_main2.txt', 'sf1_n10_det_main.txt']
direc = './training_results'
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if x in fnames]
param_val = {} #fname -> param_val -> list of times
names = []
params = []
for FNAME in training_fnames:
    print(FNAME)
    param_val[FNAME] = {}
    with open(FNAME, "r") as file:
        for line in file:
            d = eval(line)

            params = [p for p in d["params"] if p['spark_param']]
            names = [p['name'] for p in d["params"] if p['spark_param']]
            runtimes = d["runtimes"]
            if len(runtimes) == 0:
                continue

            all_default = True
            varying_param = 'default'
            varying_val = ''
            for p in params:
                if str(p['cur_value']) != str(p['default_value']):
                    varying_param = p['name']
                    varying_val = p['cur_value']
                    all_default = False
                    break
            param_val[FNAME].setdefault(f'{varying_param}_{varying_val}',[]).append(runtimes)
# Out:
# ./training_results/sf1_n10_det_main2.txt
# ./training_results/sf1_n10_det_main.txt

# %%
pvals = {} # fname -> param -> best val
for FNAME in param_val:
    print(fname)
    pvals[FNAME] = {}
    afname = "AVG_"+FNAME
    pvals[afname] = {}
    for pname in sorted(names):
        
        defa = [p['default_value'] for p in params if p['name'] == pname][0]
        print(pname, ": --- ", defa)
        vals = [(np.median([x['total'] for x in rt]), pv) for pv, rt in param_val[FNAME].items() if pname in pv or pv == 'default_']
        vals = sorted(vals)
        if vals[0][1] == 'default_':
            pvals[FNAME][pname] = defa
        else:
            pvals[FNAME][pname] = vals[0][1].split("_")[1] 
        
        avg_vals = [(np.average([x['total'] for x in rt]), pv) for pv, rt in param_val[FNAME].items() if pname in pv or pv == 'default_']
        avg_vals = sorted(avg_vals)
        if avg_vals[0][1] == 'default_':
            pvals[afname][pname] = defa
        else:
            pvals[afname][pname] = avg_vals[0][1].split("_")[1] 
            
        for i, v in enumerate(vals):
            print(f'{v[1]}: {round(v[0], 3)} sec,  AVG {avg_vals[i][1].split("_")[1]}: {round(avg_vals[i][0], 3)} sec, {len(param_val[FNAME][v[1]] if "default" not in v[1] else param_val[FNAME]["default_"])}')
        print("---")
# Out:
# ./training_results/sf10_n10_det_main_fix.txt
# spark.broadcast.blockSize : ---  4m
# spark.broadcast.blockSize_6m: 49.752 sec,  AVG 24m: 60.063 sec, 9
# spark.broadcast.blockSize_12m: 49.873 sec,  AVG 8m: 61.555 sec, 9
# spark.broadcast.blockSize_14m: 49.897 sec,  AVG 16m: 62.697 sec, 9
# default_: 50.261 sec,  AVG 18m: 63.353 sec, 10
# spark.broadcast.blockSize_18m: 50.569 sec,  AVG 10m: 63.901 sec, 9
# spark.broadcast.blockSize_24m: 50.69 sec,  AVG : 65.761 sec, 9
# spark.broadcast.blockSize_10m: 50.739 sec,  AVG 14m: 66.312 sec, 9
# spark.broadcast.blockSize_20m: 50.929 sec,  AVG 6m: 67.576 sec, 9
# spark.broadcast.blockSize_8m: 51.182 sec,  AVG 22m: 67.763 sec, 9
# spark.broadcast.blockSize_22m: 51.404 sec,  AVG 20m: 71.594 sec, 9
# spark.broadcast.blockSize_16m: 51.958 sec,  AVG 12m: 74.965 sec, 9
# ---
# spark.broadcast.compress : ---  true
# spark.broadcast.compress_false: 49.69 sec,  AVG false: 63.064 sec, 9
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# spark.default.parallelism : ---  200
# spark.default.parallelism_100: 48.881 sec,  AVG 380: 54.796 sec, 10
# spark.default.parallelism_300: 49.176 sec,  AVG 100: 54.859 sec, 10
# spark.default.parallelism_380: 49.501 sec,  AVG 220: 55.684 sec, 10
# spark.default.parallelism_220: 49.502 sec,  AVG 60: 55.954 sec, 10
# spark.default.parallelism_60: 49.536 sec,  AVG 260: 56.277 sec, 10
# spark.default.parallelism_180: 49.548 sec,  AVG 180: 56.31 sec, 10
# spark.default.parallelism_260: 49.599 sec,  AVG 140: 56.459 sec, 10
# spark.default.parallelism_140: 49.839 sec,  AVG 300: 56.589 sec, 10
# spark.default.parallelism_340: 50.085 sec,  AVG 340: 57.533 sec, 10
# default_: 50.261 sec,  AVG 20: 58.385 sec, 10
# spark.default.parallelism_20: 50.52 sec,  AVG : 65.761 sec, 10
# ---
# spark.driver.cores : ---  1
# spark.driver.cores_2: 49.496 sec,  AVG 3: 61.309 sec, 9
# spark.driver.cores_3: 49.713 sec,  AVG 4: 61.455 sec, 9
# spark.driver.cores_4: 50.057 sec,  AVG 2: 64.315 sec, 9
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# spark.driver.memory : ---  1g
# spark.driver.memory_4g: 44.387 sec,  AVG 4g: 55.558 sec, 9
# spark.driver.memory_3g: 45.684 sec,  AVG 2g: 55.57 sec, 9
# spark.driver.memory_2g: 46.47 sec,  AVG 3g: 58.968 sec, 9
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# spark.executor.cores : ---  1
# spark.executor.cores_2: 49.706 sec,  AVG 5: 54.738 sec, 10
# spark.executor.cores_3: 49.749 sec,  AVG 7: 57.97 sec, 10
# spark.executor.cores_7: 49.757 sec,  AVG 4: 58.853 sec, 10
# spark.executor.cores_5: 49.772 sec,  AVG 6: 58.859 sec, 10
# spark.executor.cores_8: 49.941 sec,  AVG 8: 60.062 sec, 10
# spark.executor.cores_4: 50.014 sec,  AVG 2: 64.581 sec, 10
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# spark.executor.cores_6: 50.366 sec,  AVG 3: 68.965 sec, 10
# ---
# spark.executor.instances : ---  2
# spark.executor.instances_3: 49.922 sec,  AVG 5: 58.32 sec, 9
# spark.executor.instances_6: 50.087 sec,  AVG 7: 59.434 sec, 9
# default_: 50.261 sec,  AVG 4: 59.879 sec, 10
# spark.executor.instances_4: 50.43 sec,  AVG 6: 60.49 sec, 9
# spark.executor.instances_5: 50.671 sec,  AVG 3: 61.65 sec, 9
# spark.executor.instances_8: 50.988 sec,  AVG 8: 62.669 sec, 9
# spark.executor.instances_7: 51.622 sec,  AVG : 65.761 sec, 9
# ---
# spark.executor.memory : ---  1g
# spark.executor.memory_7g: 49.419 sec,  AVG 3g: 57.184 sec, 9
# spark.executor.memory_2g: 49.524 sec,  AVG 2g: 59.019 sec, 10
# spark.executor.memory_5g: 49.684 sec,  AVG 4g: 59.646 sec, 9
# spark.executor.memory_4g: 49.723 sec,  AVG 8g: 59.788 sec, 9
# spark.executor.memory_8g: 49.725 sec,  AVG 5g: 60.574 sec, 9
# spark.executor.memory_6g: 49.728 sec,  AVG 6g: 60.735 sec, 9
# spark.executor.memory_3g: 49.834 sec,  AVG 7g: 61.633 sec, 9
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# spark.io.compression.codec : ---  lz4
# spark.io.compression.codec_snappy: 48.884 sec,  AVG snappy: 56.379 sec, 9
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# spark.memory.fraction : ---  0.6
# spark.memory.fraction_0.8: 49.658 sec,  AVG 0.8: 57.739 sec, 9
# default_: 50.261 sec,  AVG 0.7: 65.548 sec, 10
# spark.memory.fraction_0.7: 50.477 sec,  AVG : 65.761 sec, 9
# spark.memory.fraction_0.5: 50.683 sec,  AVG 0.3: 71.956 sec, 9
# spark.memory.fraction_0.4: 51.458 sec,  AVG 0.5: 72.358 sec, 9
# spark.memory.fraction_0.3: 52.571 sec,  AVG 0.4: 81.716 sec, 9
# ---
# spark.memory.storageFraction : ---  0.5
# spark.memory.storageFraction_0.7: 48.913 sec,  AVG 0.4: 53.896 sec, 9
# spark.memory.storageFraction_0.6: 49.398 sec,  AVG 0.7: 56.85 sec, 9
# spark.memory.storageFraction_0.8: 49.569 sec,  AVG 0.3: 57.091 sec, 9
# spark.memory.storageFraction_0.4: 49.863 sec,  AVG 0.6: 58.802 sec, 9
# default_: 50.261 sec,  AVG 0.8: 61.576 sec, 10
# spark.memory.storageFraction_0.3: 50.71 sec,  AVG : 65.761 sec, 9
# ---
# spark.rdd.compress : ---  false
# spark.rdd.compress_true: 49.696 sec,  AVG true: 56.57 sec, 9
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# spark.reducer.maxSizeInFlight : ---  48m
# spark.reducer.maxSizeInFlight_80m: 49.271 sec,  AVG 96m: 61.9 sec, 9
# spark.reducer.maxSizeInFlight_88m: 49.517 sec,  AVG 80m: 64.988 sec, 9
# spark.reducer.maxSizeInFlight_64m: 49.632 sec,  AVG : 65.761 sec, 9
# spark.reducer.maxSizeInFlight_56m: 49.69 sec,  AVG 88m: 67.857 sec, 9
# spark.reducer.maxSizeInFlight_96m: 49.911 sec,  AVG 72m: 68.798 sec, 9
# spark.reducer.maxSizeInFlight_72m: 49.991 sec,  AVG 56m: 71.293 sec, 9
# default_: 50.261 sec,  AVG 64m: 71.685 sec, 10
# ---
# spark.rpc.message.maxSize : ---  128
# spark.rpc.message.maxSize_256: 49.158 sec,  AVG 192: 56.038 sec, 9
# spark.rpc.message.maxSize_192: 49.618 sec,  AVG 160: 56.392 sec, 9
# spark.rpc.message.maxSize_224: 49.695 sec,  AVG 224: 56.664 sec, 9
# spark.rpc.message.maxSize_160: 49.778 sec,  AVG 256: 57.09 sec, 9
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# spark.shuffle.compress : ---  true
# spark.shuffle.compress_false: 48.243 sec,  AVG false: 60.459 sec, 9
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# spark.shuffle.file.buffer : ---  32k
# spark.shuffle.file.buffer_64k: 49.912 sec,  AVG 48k: 62.41 sec, 9
# default_: 50.261 sec,  AVG 64k: 64.991 sec, 10
# spark.shuffle.file.buffer_48k: 50.691 sec,  AVG : 65.761 sec, 9
# spark.shuffle.file.buffer_80k: 51.758 sec,  AVG 96k: 66.486 sec, 9
# spark.shuffle.file.buffer_112k: 52.339 sec,  AVG 128k: 69.429 sec, 9
# spark.shuffle.file.buffer_96k: 52.353 sec,  AVG 112k: 69.885 sec, 9
# spark.shuffle.file.buffer_128k: 52.529 sec,  AVG 80k: 73.891 sec, 9
# ---
# spark.shuffle.spill.compress : ---  true
# spark.shuffle.spill.compress_false: 49.337 sec,  AVG : 65.761 sec, 9
# default_: 50.261 sec,  AVG false: 66.676 sec, 10
# ---
# spark.sql.shuffle.partitions : ---  100
# spark.sql.shuffle.partitions_50: 46.891 sec,  AVG 60: 51.435 sec, 9
# spark.sql.shuffle.partitions_60: 47.138 sec,  AVG 50: 52.847 sec, 9
# spark.sql.shuffle.partitions_70: 47.546 sec,  AVG 70: 54.686 sec, 9
# spark.sql.shuffle.partitions_90: 48.588 sec,  AVG 80: 54.783 sec, 9
# spark.sql.shuffle.partitions_80: 48.603 sec,  AVG 90: 55.574 sec, 9
# spark.sql.shuffle.partitions_110: 50.063 sec,  AVG 120: 56.263 sec, 9
# default_: 50.261 sec,  AVG 110: 56.84 sec, 10
# spark.sql.shuffle.partitions_120: 51.084 sec,  AVG 130: 56.9 sec, 9
# spark.sql.shuffle.partitions_130: 51.183 sec,  AVG 140: 57.565 sec, 9
# spark.sql.shuffle.partitions_140: 51.877 sec,  AVG : 65.761 sec, 9
# ---
# spark.task.cpus : ---  1
# default_: 50.261 sec,  AVG : 65.761 sec, 10
# ---
# ./training_results/sf10_n10_det_main_fix.txt
# spark.broadcast.blockSize : ---  4m
# spark.broadcast.blockSize_14m: 85.621 sec,  AVG 14m: 77.298 sec, 5
# spark.broadcast.blockSize_20m: 85.769 sec,  AVG 10m: 78.071 sec, 5
# spark.broadcast.blockSize_24m: 86.024 sec,  AVG 20m: 78.494 sec, 5
# spark.broadcast.blockSize_10m: 86.049 sec,  AVG 24m: 78.653 sec, 5
# spark.broadcast.blockSize_12m: 86.496 sec,  AVG 22m: 79.0 sec, 5
# spark.broadcast.blockSize_22m: 86.752 sec,  AVG 12m: 79.116 sec, 5
# default_: 87.094 sec,  AVG 16m: 79.639 sec, 5
# spark.broadcast.blockSize_6m: 87.227 sec,  AVG 6m: 79.735 sec, 5
# spark.broadcast.blockSize_16m: 87.813 sec,  AVG 8m: 79.921 sec, 5
# spark.broadcast.blockSize_8m: 88.657 sec,  AVG 18m: 82.379 sec, 5
# spark.broadcast.blockSize_18m: 89.15 sec,  AVG : 87.859 sec, 5
# ---
# spark.broadcast.compress : ---  true
# spark.broadcast.compress_false: 84.742 sec,  AVG false: 76.818 sec, 5
# default_: 87.094 sec,  AVG : 87.859 sec, 5
# ---
# spark.default.parallelism : ---  200
# spark.default.parallelism_20: 81.881 sec,  AVG 20: 75.443 sec, 5
# spark.default.parallelism_380: 84.138 sec,  AVG 380: 76.834 sec, 5
# spark.default.parallelism_140: 85.209 sec,  AVG 140: 77.212 sec, 5
# spark.default.parallelism_100: 86.183 sec,  AVG 340: 78.361 sec, 5
# spark.default.parallelism_180: 86.384 sec,  AVG 100: 78.648 sec, 5
# spark.default.parallelism_340: 86.482 sec,  AVG 300: 78.761 sec, 5
# spark.default.parallelism_300: 87.072 sec,  AVG 220: 78.864 sec, 5
# default_: 87.094 sec,  AVG 260: 79.079 sec, 5
# spark.default.parallelism_260: 87.289 sec,  AVG 180: 81.326 sec, 5
# spark.default.parallelism_60: 87.385 sec,  AVG 60: 81.67 sec, 5
# spark.default.parallelism_220: 87.724 sec,  AVG : 87.859 sec, 5
# ---
# spark.driver.cores : ---  1
# spark.driver.cores_2: 86.266 sec,  AVG 4: 78.7 sec, 5
# default_: 87.094 sec,  AVG 2: 78.819 sec, 5
# spark.driver.cores_4: 87.734 sec,  AVG 3: 83.14 sec, 5
# spark.driver.cores_3: 88.115 sec,  AVG : 87.859 sec, 5
# ---
# spark.driver.memory : ---  1g
# spark.driver.memory_3g: 82.951 sec,  AVG 3g: 74.48 sec, 5
# spark.driver.memory_4g: 83.652 sec,  AVG 4g: 75.133 sec, 5
# spark.driver.memory_2g: 85.069 sec,  AVG 2g: 76.473 sec, 5
# default_: 87.094 sec,  AVG : 87.859 sec, 5
# ---
# spark.executor.cores : ---  1
# spark.executor.cores_8: 84.372 sec,  AVG 8: 76.811 sec, 5
# spark.executor.cores_5: 84.561 sec,  AVG 7: 77.595 sec, 5
# spark.executor.cores_2: 85.317 sec,  AVG 5: 85.07 sec, 5
# spark.executor.cores_7: 85.771 sec,  AVG 2: 85.172 sec, 5
# spark.executor.cores_4: 86.37 sec,  AVG 6: 86.679 sec, 5
# spark.executor.cores_3: 86.675 sec,  AVG 3: 87.708 sec, 5
# spark.executor.cores_6: 86.76 sec,  AVG : 87.859 sec, 5
# default_: 87.094 sec,  AVG 4: 91.557 sec, 5
# ---
# spark.executor.instances : ---  2
# spark.executor.instances_8: 83.57 sec,  AVG 8: 76.493 sec, 5
# spark.executor.instances_3: 84.895 sec,  AVG 3: 77.224 sec, 5
# spark.executor.instances_7: 85.107 sec,  AVG 6: 77.409 sec, 5
# spark.executor.instances_5: 85.138 sec,  AVG 5: 77.954 sec, 5
# spark.executor.instances_4: 85.167 sec,  AVG 4: 78.458 sec, 5
# spark.executor.instances_6: 85.94 sec,  AVG 7: 78.486 sec, 5
# default_: 87.094 sec,  AVG : 87.859 sec, 5
# ---
# spark.executor.memory : ---  1g
# spark.executor.memory_8g: 84.089 sec,  AVG 4g: 77.663 sec, 5
# spark.executor.memory_4g: 85.804 sec,  AVG 6g: 77.984 sec, 5
# spark.executor.memory_3g: 85.928 sec,  AVG 2g: 78.433 sec, 5
# spark.executor.memory_7g: 86.264 sec,  AVG 5g: 78.439 sec, 5
# spark.executor.memory_2g: 86.901 sec,  AVG 3g: 78.86 sec, 5
# spark.executor.memory_6g: 86.948 sec,  AVG 7g: 78.863 sec, 5
# default_: 87.094 sec,  AVG 8g: 80.643 sec, 5
# spark.executor.memory_5g: 87.778 sec,  AVG : 87.859 sec, 5
# ---
# spark.io.compression.codec : ---  lz4
# spark.io.compression.codec_snappy: 85.717 sec,  AVG snappy: 77.724 sec, 5
# default_: 87.094 sec,  AVG : 87.859 sec, 5
# ---
# spark.memory.fraction : ---  0.6
# spark.memory.fraction_0.5: 85.713 sec,  AVG 0.8: 77.241 sec, 5
# spark.memory.fraction_0.8: 85.783 sec,  AVG 0.7: 77.361 sec, 5
# spark.memory.fraction_0.7: 85.925 sec,  AVG 0.5: 77.495 sec, 5
# spark.memory.fraction_0.4: 86.632 sec,  AVG 0.3: 79.934 sec, 5
# default_: 87.094 sec,  AVG 0.4: 82.511 sec, 5
# spark.memory.fraction_0.3: 87.124 sec,  AVG : 87.859 sec, 5
# ---
# spark.memory.storageFraction : ---  0.5
# spark.memory.storageFraction_0.6: 86.623 sec,  AVG 0.7: 86.206 sec, 4
# spark.memory.storageFraction_0.3: 86.755 sec,  AVG 0.6: 86.536 sec, 4
# spark.memory.storageFraction_0.7: 87.012 sec,  AVG 0.3: 86.638 sec, 4
# default_: 87.094 sec,  AVG 0.4: 87.624 sec, 5
# spark.memory.storageFraction_0.8: 87.469 sec,  AVG : 87.859 sec, 4
# spark.memory.storageFraction_0.4: 87.689 sec,  AVG 0.8: 93.039 sec, 4
# ---
# spark.rdd.compress : ---  false
# spark.rdd.compress_true: 86.515 sec,  AVG true: 78.692 sec, 5
# default_: 87.094 sec,  AVG : 87.859 sec, 5
# ---
# spark.reducer.maxSizeInFlight : ---  48m
# spark.reducer.maxSizeInFlight_72m: 85.516 sec,  AVG 72m: 76.606 sec, 5
# spark.reducer.maxSizeInFlight_80m: 86.149 sec,  AVG 80m: 77.923 sec, 5
# spark.reducer.maxSizeInFlight_88m: 86.183 sec,  AVG 88m: 78.137 sec, 5
# spark.reducer.maxSizeInFlight_64m: 86.544 sec,  AVG 64m: 78.351 sec, 5
# spark.reducer.maxSizeInFlight_96m: 86.549 sec,  AVG 56m: 79.507 sec, 5
# default_: 87.094 sec,  AVG 96m: 81.027 sec, 5
# spark.reducer.maxSizeInFlight_56m: 88.494 sec,  AVG : 87.859 sec, 5
# ---
# spark.rpc.message.maxSize : ---  128
# spark.rpc.message.maxSize_224: 85.099 sec,  AVG 160: 78.455 sec, 5
# default_: 87.094 sec,  AVG 192: 79.404 sec, 5
# spark.rpc.message.maxSize_160: 87.232 sec,  AVG 256: 79.444 sec, 5
# spark.rpc.message.maxSize_256: 87.519 sec,  AVG 224: 81.66 sec, 5
# spark.rpc.message.maxSize_192: 89.144 sec,  AVG : 87.859 sec, 5
# ---
# spark.shuffle.compress : ---  true
# spark.shuffle.compress_false: 87.057 sec,  AVG false: 82.236 sec, 5
# default_: 87.094 sec,  AVG : 87.859 sec, 5
# ---
# spark.shuffle.file.buffer : ---  32k
# spark.shuffle.file.buffer_48k: 85.425 sec,  AVG 48k: 78.238 sec, 5
# spark.shuffle.file.buffer_64k: 86.606 sec,  AVG 128k: 78.833 sec, 5
# spark.shuffle.file.buffer_80k: 86.98 sec,  AVG 80k: 78.969 sec, 5
# default_: 87.094 sec,  AVG 96k: 79.292 sec, 5
# spark.shuffle.file.buffer_128k: 87.174 sec,  AVG 64k: 79.767 sec, 5
# spark.shuffle.file.buffer_112k: 87.994 sec,  AVG 112k: 80.29 sec, 5
# spark.shuffle.file.buffer_96k: 88.359 sec,  AVG : 87.859 sec, 5
# ---
# spark.shuffle.spill.compress : ---  true
# spark.shuffle.spill.compress_false: 84.967 sec,  AVG false: 76.85 sec, 5
# default_: 87.094 sec,  AVG : 87.859 sec, 5
# ---
# spark.sql.shuffle.partitions : ---  100
# spark.sql.shuffle.partitions_50: 79.543 sec,  AVG 50: 73.215 sec, 5
# spark.sql.shuffle.partitions_60: 82.643 sec,  AVG 60: 74.523 sec, 5
# spark.sql.shuffle.partitions_70: 84.504 sec,  AVG 110: 77.677 sec, 5
# spark.sql.shuffle.partitions_80: 85.847 sec,  AVG 90: 78.474 sec, 5
# spark.sql.shuffle.partitions_90: 86.037 sec,  AVG 130: 80.054 sec, 5
# spark.sql.shuffle.partitions_110: 86.322 sec,  AVG 80: 80.231 sec, 5
# spark.sql.shuffle.partitions_130: 86.532 sec,  AVG 120: 80.523 sec, 5
# default_: 87.094 sec,  AVG 140: 81.007 sec, 5
# spark.sql.shuffle.partitions_140: 89.242 sec,  AVG 70: 82.291 sec, 5
# spark.sql.shuffle.partitions_120: 89.408 sec,  AVG : 87.859 sec, 5
# ---
# spark.task.cpus : ---  1
# default_: 87.094 sec,  AVG : 87.859 sec, 5
# ---

# %%
# somewhat good result? -- handtuning sometimes selected the same parameters across both

#training_fnames
#pvals[FNAME][pname] = defa
print(training_fnames)
for pname in sorted(names):
    print(f"'{pname}': ", pvals[training_fnames[0]][pname], pvals[training_fnames[1]][pname], "AVG", pvals["AVG_"+training_fnames[0]][pname], pvals["AVG_"+training_fnames[1]][pname])
# Out:
# ['./training_results/sf1_n10_det_main2.txt', './training_results/sf1_n10_det_main.txt']
# 'spark.broadcast.blockSize':  6m 14m AVG 24m 14m
# 'spark.broadcast.compress':  false false AVG false false
# 'spark.default.parallelism':  100 20 AVG 380 20
# 'spark.driver.cores':  2 2 AVG 3 4
# 'spark.driver.memory':  4g 3g AVG 4g 3g
# 'spark.executor.cores':  2 8 AVG 5 8
# 'spark.executor.instances':  3 8 AVG 5 8
# 'spark.executor.memory':  7g 8g AVG 3g 4g
# 'spark.io.compression.codec':  snappy snappy AVG snappy snappy
# 'spark.memory.fraction':  0.8 0.5 AVG 0.8 0.8
# 'spark.memory.storageFraction':  0.7 0.6 AVG 0.4 0.7
# 'spark.rdd.compress':  true true AVG true true
# 'spark.reducer.maxSizeInFlight':  80m 72m AVG 96m 72m
# 'spark.rpc.message.maxSize':  256 224 AVG 192 160
# 'spark.shuffle.compress':  false false AVG false false
# 'spark.shuffle.file.buffer':  64k 48k AVG 48k 48k
# 'spark.shuffle.spill.compress':  false false AVG true false
# 'spark.sql.shuffle.partitions':  50 50 AVG 60 50
# 'spark.task.cpus':  1 1 AVG 1 1

# %%
hand_tuning = {
'spark.broadcast.blockSize':  '14m',
'spark.broadcast.compress':  'false',
'spark.default.parallelism':  '20',
'spark.driver.cores':  '3',
'spark.driver.memory':  '4g',
'spark.executor.cores':  '8',
'spark.executor.instances':  '8',
'spark.executor.memory':  '4g',
'spark.io.compression.codec':  'snappy',
'spark.memory.fraction':  '0.8',
'spark.memory.storageFraction':  '0.7',
'spark.rdd.compress':  'true', 
'spark.reducer.maxSizeInFlight':  '80m',
'spark.rpc.message.maxSize': '192',
'spark.shuffle.compress':  'false',
'spark.shuffle.file.buffer':  '48k',
'spark.shuffle.spill.compress':  'false', 
'spark.sql.shuffle.partitions':  '50',
'spark.task.cpus':  '1',  
}
