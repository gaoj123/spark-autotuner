# %%
import os 
import sys 
import time 
import numpy as np
import json
import tpch_param as tp

# %%
DET_PARAMS_FNAME = "./training_params/detparams_n10.json"
DET_PARAMS = None
with open(DET_PARAMS_FNAME, 'rb') as f:
    DET_PARAMS = json.load(f)
    print(len(DET_PARAMS))

training_fnames = ['./training_results/'+x for x in os.listdir('./training_results') if 'sf10_' in x and 'main' in x]
len(training_fnames)
print(training_fnames)

def get_spark_params(result_dict):
    param_vals = []
    for param in tp.SPARK_PARAMETERS:
        for p in result_dict['params']:
            if p['name'] == param['name']:
                param_vals.append(p['cur_value'])
    return tuple(param_vals)
# Out:
# 880
# ['./training_results/sf10_n1_rand_main1.txt', './training_results/sf10_n1_rand_main2.txt', './training_results/sf10_n10_det_main0.txt', './training_results/sf10_n1_rand_main6.txt', './training_results/sf10_n1_rand_main3.txt', './training_results/sf10_n1_rand_main8.txt', './training_results/sf10_n1_rand_main7.txt', './training_results/sf10_n1_rand_main9.txt', './training_results/sf10_n10_det_main_fix.txt', './training_results/sf10_n1_rand_main_fix.txt', './training_results/sf10_n1_rand_main0.txt', './training_results/sf10_n1_rand_main4.txt', './training_results/sf10_n1_rand_main5.txt']

# %%
defaults = tuple(a['default_value'] for a in tp.SPARK_PARAMETERS)
defaults
# Out:
# (1,
#  '1g',
#  2,
#  1,
#  '1g',
#  '48m',
#  'true',
#  'true',
#  '32k',
#  '4m',
#  'true',
#  0.6,
#  '128',
#  'false',
#  'lz4',
#  1,
#  100,
#  200,
#  0.5)

# %%
fname_numdata = {}
fname_numdet = {}
deterministic_data = {}

for fname in training_fnames:
    with open(fname,'r') as file:
        lines = file.readlines()
        fname_numdata[fname] = len(lines)
        deterministic_data[fname] = {}
        
        for k in DET_PARAMS:
            if int(k) < len(lines):
                deterministic_data[fname][k] = eval(lines[int(k)])
        fname_numdet[fname] = len(deterministic_data[fname])
        if fname_numdet[fname] < 5:
            del fname_numdet[fname]
            del deterministic_data[fname]
            
print(sum(fname_numdata.values()))
print(fname_numdata)
print(fname_numdet)
# Out:
# 3288
# {'./training_results/sf10_n1_rand_main1.txt': 342, './training_results/sf10_n1_rand_main2.txt': 234, './training_results/sf10_n10_det_main0.txt': 266, './training_results/sf10_n1_rand_main6.txt': 310, './training_results/sf10_n1_rand_main3.txt': 89, './training_results/sf10_n1_rand_main8.txt': 282, './training_results/sf10_n1_rand_main7.txt': 294, './training_results/sf10_n1_rand_main9.txt': 251, './training_results/sf10_n10_det_main_fix.txt': 313, './training_results/sf10_n1_rand_main_fix.txt': 336, './training_results/sf10_n1_rand_main0.txt': 230, './training_results/sf10_n1_rand_main4.txt': 115, './training_results/sf10_n1_rand_main5.txt': 226}
# {'./training_results/sf10_n1_rand_main1.txt': 342, './training_results/sf10_n1_rand_main2.txt': 234, './training_results/sf10_n10_det_main0.txt': 266, './training_results/sf10_n1_rand_main6.txt': 310, './training_results/sf10_n1_rand_main3.txt': 89, './training_results/sf10_n1_rand_main8.txt': 282, './training_results/sf10_n1_rand_main7.txt': 294, './training_results/sf10_n1_rand_main9.txt': 251, './training_results/sf10_n10_det_main_fix.txt': 313, './training_results/sf10_n1_rand_main_fix.txt': 336, './training_results/sf10_n1_rand_main0.txt': 230, './training_results/sf10_n1_rand_main4.txt': 115, './training_results/sf10_n1_rand_main5.txt': 226}

# %%
det_params = {}
det_rt = {}
for fname, data in deterministic_data.items():
    det_params[fname] = []
    det_rt[fname] = []
    for result_dict in data.values():
        det_params[fname].append(get_spark_params(result_dict))
        if result_dict['runtimes']:
            det_rt[fname].append(result_dict['runtimes']['total']) # total
    if not det_params[fname]:
        print(fname)
        del det_params[fname]
        del det_rt[fname]
prev_fname = fname
for fname in det_params:
    assert 'det' not in fname or det_params[fname][0] == defaults, f'{det_params[fname][0]} !=\n{defaults}'
    #assert str(det_params[fname]) == str(det_params[prev_fname]), fname + " " + prev_fname
    print(fname, '\n',det_rt[fname][0], det_rt[fname][-1], max(det_rt[fname]), min(det_rt[fname]), len(det_rt[fname]))
# Out:
# ./training_results/sf10_n1_rand_main1.txt
#  230.9756691455841 172.565904378891 481.46935844421387 113.8074905872345 311
# ./training_results/sf10_n1_rand_main2.txt
#  206.01829862594604 547.7919764518738 962.8571968078613 111.53646945953369 213
# ./training_results/sf10_n10_det_main0.txt
#  256.333726644516 184.70234084129333 644.3383266925812 112.67993021011353 261
# ./training_results/sf10_n1_rand_main6.txt
#  273.2982528209686 279.40095472335815 774.4564828872681 121.7477240562439 292
# ./training_results/sf10_n1_rand_main3.txt
#  499.5033097267151 889.0193419456482 1071.9683856964111 433.37639260292053 84
# ./training_results/sf10_n1_rand_main8.txt
#  273.0497591495514 251.90045142173767 707.8546605110168 133.60163044929504 261
# ./training_results/sf10_n1_rand_main7.txt
#  280.8402376174927 206.59541630744934 693.18909907341 127.12500834465027 277
# ./training_results/sf10_n1_rand_main9.txt
#  329.3771061897278 265.32997584342957 483.8762583732605 142.33520579338074 235
# ./training_results/sf10_n10_det_main_fix.txt
#  191.07653999328613 181.95806455612183 209.71132683753967 119.95743799209595 307
# ./training_results/sf10_n1_rand_main_fix.txt
#  147.78749179840088 144.14588046073914 272.792964220047 117.69698166847229 310
# ./training_results/sf10_n1_rand_main0.txt
#  229.00366067886353 337.3463258743286 712.7956547737122 154.3426637649536 224
# ./training_results/sf10_n1_rand_main4.txt
#  493.91465878486633 764.9570002555847 1156.0497951507568 403.3373279571533 85
# ./training_results/sf10_n1_rand_main5.txt
#  856.3335855007172 153.19395518302917 1206.5933125019073 115.62407279014587 175

# %%
# how many different param combos have we tried?
fname_num_params = {}
fname_valid = {}
for fname in training_fnames:
    with open(fname,'r') as file:
        lines = file.readlines()
        fname_num_params[fname] = set()
        fname_valid[fname] = 0
        for result_dict in lines:
            result_dict = eval(result_dict)
            fname_num_params[fname].add(get_spark_params(result_dict))
            fname_valid[fname] += 1 if result_dict['runtimes'] else 0

# %%
print(sum([len(x) for x in fname_num_params.values()]))
for fname, vals in fname_num_params.items():
    print(fname[18:60], '\nnum unique params', len(vals), 'total runs',fname_numdata[fname] , 'valid runs', fname_valid[fname])
# Out:
# 2885
# /sf10_n1_rand_main1.txt
# num unique params 342 total runs 342 valid runs 311
# /sf10_n1_rand_main2.txt
# num unique params 234 total runs 234 valid runs 213
# /sf10_n10_det_main0.txt
# num unique params 88 total runs 266 valid runs 261
# /sf10_n1_rand_main6.txt
# num unique params 310 total runs 310 valid runs 292
# /sf10_n1_rand_main3.txt
# num unique params 89 total runs 89 valid runs 84
# /sf10_n1_rand_main8.txt
# num unique params 282 total runs 282 valid runs 261
# /sf10_n1_rand_main7.txt
# num unique params 294 total runs 294 valid runs 277
# /sf10_n1_rand_main9.txt
# num unique params 251 total runs 251 valid runs 235
# /sf10_n10_det_main_fix.txt
# num unique params 88 total runs 313 valid runs 307
# /sf10_n1_rand_main_fix.txt
# num unique params 336 total runs 336 valid runs 310
# /sf10_n1_rand_main0.txt
# num unique params 230 total runs 230 valid runs 224
# /sf10_n1_rand_main4.txt
# num unique params 115 total runs 115 valid runs 85
# /sf10_n1_rand_main5.txt
# num unique params 226 total runs 226 valid runs 175

# %%
#det_rt

# %%
for fname in det_rt:
    all_runs = []
    runs = []
    for run in det_rt[fname]:
        all_runs.append(run)
        runs.append(run)
    print(fname, 'avg ', round(np.average(runs), 5), 'median', round(np.median(runs), 5), 'range ', round(max(runs)-min(runs),5), 'std ', round(np.std(runs), 5))
print('overall runs avg ', round(np.average(all_runs), 5), 'median', round(np.median(all_runs), 5), 'range ', round(max(all_runs)-min(all_runs),5), 'std ', round(np.std(all_runs), 5))
# Out:
# ./training_results/sf10_n1_rand_main1.txt avg  174.69546 median 184.16709 range  367.66187 std  44.71078
# ./training_results/sf10_n1_rand_main2.txt avg  263.45368 median 192.50177 range  851.32073 std  210.50907
# ./training_results/sf10_n10_det_main0.txt avg  217.36596 median 215.74945 range  531.6584 std  48.53312
# ./training_results/sf10_n1_rand_main6.txt avg  192.59737 median 202.11601 range  652.70876 std  65.51455
# ./training_results/sf10_n1_rand_main3.txt avg  702.93445 median 588.02553 range  638.59199 std  214.78939
# ./training_results/sf10_n1_rand_main8.txt avg  216.62503 median 202.43023 range  574.25303 std  72.09113
# ./training_results/sf10_n1_rand_main7.txt avg  204.50371 median 194.09189 range  566.06409 std  68.23366
# ./training_results/sf10_n1_rand_main9.txt avg  242.70374 median 244.00952 range  341.54105 std  80.72452
# ./training_results/sf10_n10_det_main_fix.txt avg  182.90013 median 184.26596 range  89.75389 std  12.37005
# ./training_results/sf10_n1_rand_main_fix.txt avg  179.0944 median 185.97578 range  155.09598 std  41.7419
# ./training_results/sf10_n1_rand_main0.txt avg  256.62814 median 219.91821 range  558.45299 std  83.75954
# ./training_results/sf10_n1_rand_main4.txt avg  691.10043 median 784.00931 range  752.71247 std  212.77772
# ./training_results/sf10_n1_rand_main5.txt avg  321.10561 median 185.65078 range  1090.96924 std  281.49223
# overall runs avg  321.10561 median 185.65078 range  1090.96924 std  281.49223

# %%
#training_fnames = ['./training_results/'+x for x in os.listdir('./training_results') if 'json' in x and 'test_clear_ports' in x]
#direc = '../../../../nobackup1/hoped/spark-autotuner/training_data/training_results'
#training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'json' in x and 'nobackup_deterministic_raw_runtimes' in x]
direc = './training_results'
print (os.listdir(direc), "\n")
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'det_main' in x]
#direc = '../../../../nobackup1/hoped/spark-autotuner/training_data/training_results'

len(training_fnames)
print(training_fnames)
for FNAME in  training_fnames:
    import json
    import os
    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    
    with open(FNAME,'r') as file:
        try:
            file_data = file.readlines()
        except Exception as e:
            print(FNAME, "load error")
            print(e)
            continue
    if len(file_data) < 5:
        continue

    class Parameter:
        def __init__(self, name):
            self.name = name
            self.val_to_results = {}

        def add(self, param_val, results):
            self.val_to_results[param_val] = results

        def get_total(self, param_val):
            if param_val in self.val_to_results:
                return self.val_to_results[param_val]["total"] # change

        def get_param_vals(self):
            return set(self.val_to_results.keys())

    param_name_to_param_obj = {}

    def populate_params():
        #analyze one file

        with open(FNAME, "r") as file:
            for line in file:
                d = eval(line)
       
                params = [p for p in d["params"] if p['spark_param']]
                runtimes = d["runtimes"]
                if len(runtimes) == 0:
                    continue

                all_default = True
                for p in params:
                    if str(p['cur_value']) != str(p['default_value']):
                        varying_param = p['name']
                        all_default = False
                        break
                if all_default:
                    if 'default' not in param_name_to_param_obj:
                        param_name_to_param_obj["default"] = Parameter('default')

                    obj = param_name_to_param_obj["default"]
                    obj.add(len(obj.val_to_results), runtimes)
                    continue

                if varying_param not in param_name_to_param_obj:
                    param_name_to_param_obj[varying_param] = Parameter(varying_param)
                obj = param_name_to_param_obj[varying_param]
                assert "total" in runtimes
                obj.add(p['cur_value'], runtimes)

    def analyze_results():
        populate_params()
        default = param_name_to_param_obj["default"]
        default_total = [default.get_total(k) for k in default.get_param_vals()]
        print('deftotal',default_total)
        mins = []
        names = []
        diffs = []
        stds = []
        for p in sorted(param_name_to_param_obj):
            min_runtime = float("inf")
            max_runtime = -float("inf")
            times = []
            if p != 'default':
                obj = param_name_to_param_obj[p]
                for k in obj.get_param_vals():
                    total_time = obj.get_total(k)
                    if type(total_time) == list:
                        times.extend(total_time)
                        min_runtime = min(min_runtime, min(total_time))
                        max_runtime = max(max_runtime, max(total_time))
                    else:
                        times.append(total_time)
                        min_runtime = min(min_runtime, total_time)
                        max_runtime = max(max_runtime, total_time)
                if min_runtime == max_runtime:
                    max_runtime += .01


            else:
                times.extend(default_total)
                min_runtime = min(default_total)
                max_runtime = max(default_total)
            stds.append(np.std(times))
            if p == 'default':
                print(f"{p}, min: {round(min_runtime,5)}, max: {round(max_runtime,5)}, median {round(np.median(times),5)}, avg: {round(np.average(times),5)}  default: {round(min(default_total),5), round(max(default_total),5)}")
            mins.append(min_runtime)
            diffs.append(max_runtime - min_runtime)
            names.append(p)

        #save total time std to csv
        df = pd.DataFrame(list(zip(names, stds)),
        columns =['name', 'standard_dev_total_times'])
        df.to_csv("./training_sensitivity/all_runtime_stds.csv", mode='w')

        #plot std
        fig = plt.figure(figsize = (10, 5))
        plt.xticks(rotation=90)
        plt.bar(names, stds, bottom=[0]*len(names), width=0.2)
        plt.title("Standard deviation of total query times for each parameter")
        plt.xlabel("Parameter")
        plt.ylabel("Standard deviation of times")
        name = FNAME.split("/")[-1][:-4]
        print(name, len(file_data))
        plt.savefig(f"./training_sensitivity/all_runtime_stds{name}.jpg", bbox_inches="tight")
        plt.show()

        #plot min/max times for each parameter
        fig = plt.figure(figsize = (10, 5))
        plt.xticks(rotation=90)
        plt.bar(names, diffs, bottom=mins, width=0.2)
        plt.title("Range of total query times for each parameter")
        plt.xlabel("Parameter")
        plt.ylabel("Range of times")
        plt.savefig(f"./training_sensitivity/all_runtime_ranges{name}.jpg", bbox_inches="tight")
        plt.show()

    analyze_results()
    
# run it locally
# check number of rows that are loading
# look at and verify result to materialize the answer
# Out:
# ['sf300_n1_det_testing.txt', '.ipynb_checkpoints', 'sf1_n1_det_main2.txt', 'sf1_n5_det_main2.txt', 'sf1_n10_det_main2.txt', 'sf10_n1_rand_main1.txt', 'sf10_n1_rand_main2.txt', 'sf10_n10_det_main0.txt', 'sf10_n1_rand_main6.txt', 'sf10_n1_rand_main3.txt', 'sf10_n1_rand_main8.txt', 'sf1_n10_det_main.txt', 'sf1_n1_rand_main4.txt', 'sf1_n1_rand_main5.txt', 'sf1_n1_rand_main1.txt', 'sf1_n1_rand_main3.txt', 'sf1_n1_rand_main2.txt', 'sf10_n1_rand_main7.txt', 'sf10_n1_rand_main9.txt', 'sf10_n10_det_main_fix.txt', 'sf10_n1_rand_main_fix.txt', 'sf10_n1_rand_main0.txt', 'sf10_n1_rand_main4.txt', 'sf10_n1_rand_main5.txt', 'sf1_n20_compare_test3.txt']
#
# ['./training_results/sf1_n1_det_main2.txt', './training_results/sf1_n5_det_main2.txt', './training_results/sf1_n10_det_main2.txt', './training_results/sf10_n10_det_main0.txt', './training_results/sf1_n10_det_main.txt', './training_results/sf10_n10_det_main_fix.txt']
# deftotal [386.0415635108948]
# default, min: 386.04156, max: 386.04156, median 386.04156, avg: 386.04156  default: (386.04156, 386.04156)
# sf1_n1_det_main2 50
# deftotal [382.4356498718262]
# default, min: 382.43565, max: 382.43565, median 382.43565, avg: 382.43565  default: (382.43565, 382.43565)
# sf1_n5_det_main2 50
# deftotal [123.33979225158691, 140.57317280769348, 50.346794843673706, 50.17508149147034, 49.330902099609375, 49.20719623565674, 50.940053939819336, 50.42170023918152, 49.633732318878174, 43.64210057258606]
# default, min: 43.6421, max: 140.57317, median 50.26094, avg: 65.76105  default: (43.6421, 140.57317)
# sf1_n10_det_main2 880
# deftotal [256.333726644516, 242.2513129711151, 182.21644806861877, 183.4787199497223]
# default, min: 182.21645, max: 256.33373, median 212.86502, avg: 216.07005  default: (182.21645, 256.33373)
# sf10_n10_det_main0 267
# deftotal [91.26099371910095, 85.19530129432678, 84.05660152435303, 87.09424328804016, 91.69003963470459, 42.23882794380188, 42.6687388420105, 43.453712940216064, 42.586594581604004, 43.894917249679565]
# default, min: 42.23883, max: 91.69004, median 63.97576, avg: 65.414  default: (42.23883, 91.69004)
# sf1_n10_det_main 831
# deftotal [191.07653999328613, 186.319504737854, 183.99108695983887, 184.63133668899536]
# default, min: 183.99109, max: 191.07654, median 185.47542, avg: 186.50462  default: (183.99109, 191.07654)
# sf10_n10_det_main_fix 314

# %%
#direc = '../../../../nobackup1/hoped/spark-autotuner/training_data/training_results'
#training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'rand' in x]
direc = './training_results'
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if 'txt' in x and 'sf324_n250_rand' in x]
len(training_fnames)
print(training_fnames)

fname_numdata = {'all':0}

for fname in training_fnames:
    with open(fname,'r') as file:
        try:
            file_data = file.readlines()
            fname_numdata[fname] = len(file_data)
            fname_numdata['all'] += len(file_data)
        except:
            print("error loading", fname)
print(sum(fname_numdata.values()))

# how many different param combos have we tried?
fname_num_params = {'all':set()}
fname_valid = {'all':0}
for fname in training_fnames:
    with open(fname,'r') as file:
        try:
            file_data = file.readlines()
        except:
            print("error loading", fname)
            continue
        fname_num_params[fname] = set()
        fname_valid[fname] = 0
        for result_dict in file_data:
            result_dict = eval(result_dict)
            fname_num_params[fname].add(get_spark_params(result_dict))
            fname_valid[fname] += 1 if result_dict['runtimes'] else 0
            fname_num_params['all'].add(get_spark_params(result_dict))
            fname_valid['all'] += 1 if result_dict['runtimes'] else 0
print(sum([len(x) for x in fname_num_params.values()]))
for fname, vals in fname_num_params.items():
    if fname == 'all':
        print("all:")

    print(fname, '\nnum unique params', len(vals), 'total runs',fname_numdata[fname] , 'valid runs', fname_valid[fname])
# Out:
# []
# 0
# 0
# all:
# all
# num unique params 0 total runs 0 valid runs 0

# %%
# hand tuning = pick the lowest time for each param after one deterministic run

# %%
fnames = ['sf10_n10_det_main0.txt', 'sf10_n10_det_main_fix.txt']#
#['sf1_n10_det_main2.txt', 'sf1_n10_det_main.txt']
direc = './training_results'
training_fnames = [f'{direc}/{x}'for x in os.listdir(direc) if x in fnames]
param_val = {} #fname -> param_val -> list of times
names = []
params = []
for FNAME in training_fnames:
    print(FNAME)
    param_val[FNAME] = {}
    with open(FNAME, "r") as file:
        for line in file:
            d = eval(line)

            params = [p for p in d["params"] if p['spark_param']]
            names = [p['name'] for p in d["params"] if p['spark_param']]
            runtimes = d["runtimes"]
            if len(runtimes) == 0:
                continue

            all_default = True
            varying_param = 'default'
            varying_val = ''
            for p in params:
                if str(p['cur_value']) != str(p['default_value']):
                    varying_param = p['name']
                    varying_val = p['cur_value']
                    all_default = False
                    break
            param_val[FNAME].setdefault(f'{varying_param}_{varying_val}',[]).append(runtimes)
# Out:
# ./training_results/sf10_n10_det_main0.txt
# ./training_results/sf10_n10_det_main_fix.txt

# %%
pvals = {} # fname -> param -> best val
for FNAME in param_val:
    print(fname)
    pvals[FNAME] = {}
    afname = "AVG_"+FNAME
    pvals[afname] = {}
    for pname in sorted(names):
        
        defa = [p['default_value'] for p in params if p['name'] == pname][0]
        print(pname, ": --- ", defa)
        vals = [(np.median([x['total'] for x in rt]), pv) for pv, rt in param_val[FNAME].items() if pname in pv or pv == 'default_']
        vals = sorted(vals)
        if vals[0][1] == 'default_':
            pvals[FNAME][pname] = defa
        else:
            pvals[FNAME][pname] = vals[0][1].split("_")[1] 
        
        avg_vals = [(np.average([x['total'] for x in rt]), pv) for pv, rt in param_val[FNAME].items() if pname in pv or pv == 'default_']
        avg_vals = sorted(avg_vals)
        if avg_vals[0][1] == 'default_':
            pvals[afname][pname] = defa
        else:
            pvals[afname][pname] = avg_vals[0][1].split("_")[1] 
            
        for i, v in enumerate(vals):
            print(f'{v[1]}: {round(v[0], 3)} sec,  AVG {avg_vals[i][1].split("_")[1]}: {round(avg_vals[i][0], 3)} sec, {len(param_val[FNAME][v[1]] if "default" not in v[1] else param_val[FNAME]["default_"])}')
        print("---")
# Out:
# all
# spark.broadcast.blockSize : ---  4m
# spark.broadcast.blockSize_24m: 184.575 sec,  AVG 24m: 202.971 sec, 3
# spark.broadcast.blockSize_22m: 187.722 sec,  AVG 22m: 205.821 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# spark.broadcast.blockSize_6m: 238.564 sec,  AVG 6m: 220.47 sec, 3
# spark.broadcast.blockSize_14m: 240.281 sec,  AVG 14m: 222.331 sec, 3
# spark.broadcast.blockSize_16m: 241.855 sec,  AVG 16m: 222.678 sec, 3
# spark.broadcast.blockSize_12m: 243.62 sec,  AVG 12m: 222.695 sec, 3
# spark.broadcast.blockSize_10m: 243.689 sec,  AVG 10m: 224.417 sec, 3
# spark.broadcast.blockSize_8m: 244.117 sec,  AVG 8m: 224.45 sec, 3
# spark.broadcast.blockSize_18m: 247.398 sec,  AVG 20m: 250.886 sec, 3
# spark.broadcast.blockSize_20m: 249.125 sec,  AVG 18m: 335.312 sec, 3
# ---
# spark.broadcast.compress : ---  true
# spark.broadcast.compress_false: 186.469 sec,  AVG false: 209.834 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# spark.default.parallelism : ---  200
# spark.default.parallelism_60: 179.26 sec,  AVG 60: 196.939 sec, 4
# spark.default.parallelism_140: 181.047 sec,  AVG 140: 200.69 sec, 4
# spark.default.parallelism_180: 181.985 sec,  AVG 180: 200.772 sec, 4
# spark.default.parallelism_260: 182.261 sec,  AVG 300: 201.11 sec, 4
# spark.default.parallelism_100: 182.965 sec,  AVG 260: 201.543 sec, 4
# spark.default.parallelism_300: 182.974 sec,  AVG 100: 201.592 sec, 4
# spark.default.parallelism_220: 183.253 sec,  AVG 220: 201.994 sec, 4
# spark.default.parallelism_340: 185.048 sec,  AVG 340: 204.958 sec, 4
# spark.default.parallelism_380: 188.663 sec,  AVG 380: 207.998 sec, 4
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# spark.default.parallelism_20: 255.713 sec,  AVG 20: 255.713 sec, 4
# ---
# spark.driver.cores : ---  1
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# spark.driver.cores_3: 238.496 sec,  AVG 4: 220.7 sec, 3
# spark.driver.cores_4: 239.757 sec,  AVG 3: 221.748 sec, 3
# spark.driver.cores_2: 243.714 sec,  AVG 2: 224.039 sec, 3
# ---
# spark.driver.memory : ---  1g
# spark.driver.memory_4g: 204.875 sec,  AVG 4g: 175.161 sec, 3
# spark.driver.memory_2g: 209.141 sec,  AVG 3g: 179.811 sec, 3
# spark.driver.memory_3g: 209.724 sec,  AVG 2g: 185.827 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# spark.executor.cores : ---  1
# spark.executor.cores_3: 209.797 sec,  AVG 3: 210.107 sec, 4
# spark.executor.cores_5: 212.34 sec,  AVG 2: 212.385 sec, 4
# spark.executor.cores_2: 212.792 sec,  AVG 5: 213.479 sec, 4
# default_: 212.865 sec,  AVG 4: 214.553 sec, 4
# spark.executor.cores_4: 215.003 sec,  AVG : 216.07 sec, 4
# spark.executor.cores_6: 239.21 sec,  AVG 6: 221.385 sec, 3
# spark.executor.cores_8: 239.56 sec,  AVG 8: 221.774 sec, 3
# spark.executor.cores_7: 241.831 sec,  AVG 7: 222.006 sec, 3
# ---
# spark.executor.instances : ---  2
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# spark.executor.instances_8: 237.672 sec,  AVG 5: 221.062 sec, 3
# spark.executor.instances_7: 239.621 sec,  AVG 4: 221.812 sec, 3
# spark.executor.instances_5: 239.939 sec,  AVG 8: 222.281 sec, 3
# spark.executor.instances_6: 240.785 sec,  AVG 6: 222.697 sec, 3
# spark.executor.instances_4: 240.837 sec,  AVG 7: 223.138 sec, 3
# spark.executor.instances_3: 244.268 sec,  AVG 3: 226.08 sec, 3
# ---
# spark.executor.memory : ---  1g
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# spark.executor.memory_4g: 236.804 sec,  AVG 5g: 219.944 sec, 3
# spark.executor.memory_5g: 238.418 sec,  AVG 4g: 220.939 sec, 3
# spark.executor.memory_6g: 239.561 sec,  AVG 8g: 221.0 sec, 3
# spark.executor.memory_3g: 239.753 sec,  AVG 2g: 221.606 sec, 3
# spark.executor.memory_8g: 239.852 sec,  AVG 6g: 221.855 sec, 3
# spark.executor.memory_2g: 240.393 sec,  AVG 3g: 222.31 sec, 3
# spark.executor.memory_7g: 241.151 sec,  AVG 7g: 222.653 sec, 3
# ---
# spark.io.compression.codec : ---  lz4
# spark.io.compression.codec_snappy: 193.634 sec,  AVG snappy: 207.512 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# spark.memory.fraction : ---  0.6
# spark.memory.fraction_0.5: 184.448 sec,  AVG 0.5: 203.252 sec, 3
# spark.memory.fraction_0.7: 187.112 sec,  AVG 0.7: 204.352 sec, 3
# spark.memory.fraction_0.4: 187.633 sec,  AVG 0.8: 208.14 sec, 3
# spark.memory.fraction_0.3: 194.518 sec,  AVG 0.4: 208.793 sec, 3
# spark.memory.fraction_0.8: 197.047 sec,  AVG 0.3: 211.546 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# spark.memory.storageFraction : ---  0.5
# spark.memory.storageFraction_0.6: 181.865 sec,  AVG 0.6: 201.821 sec, 3
# spark.memory.storageFraction_0.8: 183.531 sec,  AVG 0.4: 202.48 sec, 3
# spark.memory.storageFraction_0.7: 183.864 sec,  AVG 0.7: 202.826 sec, 3
# spark.memory.storageFraction_0.4: 184.276 sec,  AVG 0.8: 202.895 sec, 3
# spark.memory.storageFraction_0.3: 184.831 sec,  AVG 0.3: 203.744 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# spark.rdd.compress : ---  false
# spark.rdd.compress_true: 183.92 sec,  AVG true: 203.595 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# spark.reducer.maxSizeInFlight : ---  48m
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# spark.reducer.maxSizeInFlight_72m: 236.405 sec,  AVG 72m: 219.73 sec, 3
# spark.reducer.maxSizeInFlight_56m: 239.298 sec,  AVG 80m: 220.932 sec, 3
# spark.reducer.maxSizeInFlight_80m: 239.364 sec,  AVG 64m: 222.483 sec, 3
# spark.reducer.maxSizeInFlight_64m: 240.447 sec,  AVG 96m: 222.566 sec, 3
# spark.reducer.maxSizeInFlight_96m: 242.214 sec,  AVG 56m: 222.87 sec, 3
# spark.reducer.maxSizeInFlight_88m: 242.479 sec,  AVG 88m: 223.393 sec, 3
# ---
# spark.rpc.message.maxSize : ---  128
# spark.rpc.message.maxSize_224: 182.357 sec,  AVG 160: 201.308 sec, 3
# spark.rpc.message.maxSize_160: 182.647 sec,  AVG 192: 201.598 sec, 3
# spark.rpc.message.maxSize_192: 182.722 sec,  AVG 224: 203.076 sec, 3
# spark.rpc.message.maxSize_256: 183.689 sec,  AVG 256: 204.399 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# spark.shuffle.compress : ---  true
# default_: 212.865 sec,  AVG false: 212.294 sec, 4
# spark.shuffle.compress_false: 232.892 sec,  AVG : 216.07 sec, 3
# ---
# spark.shuffle.file.buffer : ---  32k
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# spark.shuffle.file.buffer_48k: 243.875 sec,  AVG 48k: 225.933 sec, 3
# spark.shuffle.file.buffer_80k: 246.458 sec,  AVG 80k: 232.258 sec, 3
# spark.shuffle.file.buffer_64k: 249.778 sec,  AVG 96k: 234.97 sec, 3
# spark.shuffle.file.buffer_96k: 250.658 sec,  AVG 128k: 240.183 sec, 3
# spark.shuffle.file.buffer_128k: 251.659 sec,  AVG 112k: 295.43 sec, 3
# spark.shuffle.file.buffer_112k: 252.581 sec,  AVG 64k: 362.316 sec, 3
# ---
# spark.shuffle.spill.compress : ---  true
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# spark.shuffle.spill.compress_false: 243.349 sec,  AVG false: 225.18 sec, 3
# ---
# spark.sql.shuffle.partitions : ---  100
# spark.sql.shuffle.partitions_80: 177.891 sec,  AVG 80: 197.975 sec, 3
# spark.sql.shuffle.partitions_90: 180.193 sec,  AVG 90: 199.749 sec, 3
# spark.sql.shuffle.partitions_70: 180.522 sec,  AVG 70: 201.265 sec, 3
# spark.sql.shuffle.partitions_60: 184.022 sec,  AVG 60: 201.722 sec, 3
# spark.sql.shuffle.partitions_120: 185.944 sec,  AVG 120: 203.894 sec, 3
# spark.sql.shuffle.partitions_130: 187.861 sec,  AVG 110: 206.094 sec, 3
# spark.sql.shuffle.partitions_110: 188.092 sec,  AVG 130: 206.183 sec, 3
# spark.sql.shuffle.partitions_50: 188.87 sec,  AVG 50: 207.903 sec, 3
# spark.sql.shuffle.partitions_140: 192.069 sec,  AVG 140: 210.769 sec, 3
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# spark.task.cpus : ---  1
# default_: 212.865 sec,  AVG : 216.07 sec, 4
# ---
# all
# spark.broadcast.blockSize : ---  4m
# spark.broadcast.blockSize_6m: 183.219 sec,  AVG 6m: 183.248 sec, 4
# spark.broadcast.blockSize_16m: 183.296 sec,  AVG 10m: 183.369 sec, 4
# spark.broadcast.blockSize_20m: 183.453 sec,  AVG 16m: 183.494 sec, 4
# spark.broadcast.blockSize_12m: 183.463 sec,  AVG 12m: 183.697 sec, 4
# spark.broadcast.blockSize_10m: 183.865 sec,  AVG 20m: 184.283 sec, 4
# spark.broadcast.blockSize_18m: 184.848 sec,  AVG 18m: 184.835 sec, 4
# spark.broadcast.blockSize_8m: 185.081 sec,  AVG 8m: 185.148 sec, 4
# spark.broadcast.blockSize_14m: 185.473 sec,  AVG 14m: 185.658 sec, 4
# default_: 185.475 sec,  AVG 22m: 185.676 sec, 4
# spark.broadcast.blockSize_22m: 185.71 sec,  AVG 24m: 186.351 sec, 4
# spark.broadcast.blockSize_24m: 186.232 sec,  AVG : 186.505 sec, 4
# ---
# spark.broadcast.compress : ---  true
# spark.broadcast.compress_false: 182.504 sec,  AVG false: 182.937 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.default.parallelism : ---  200
# spark.default.parallelism_60: 180.474 sec,  AVG 60: 180.211 sec, 4
# spark.default.parallelism_100: 182.027 sec,  AVG 220: 182.185 sec, 4
# spark.default.parallelism_180: 182.544 sec,  AVG 100: 182.434 sec, 4
# spark.default.parallelism_220: 182.736 sec,  AVG 140: 183.258 sec, 4
# spark.default.parallelism_140: 183.111 sec,  AVG 180: 183.614 sec, 4
# spark.default.parallelism_300: 184.301 sec,  AVG 300: 184.974 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# spark.default.parallelism_260: 186.392 sec,  AVG 260: 186.858 sec, 4
# spark.default.parallelism_380: 187.906 sec,  AVG 340: 187.756 sec, 4
# spark.default.parallelism_340: 187.989 sec,  AVG 380: 187.906 sec, 4
# ---
# spark.driver.cores : ---  1
# spark.driver.cores_3: 183.524 sec,  AVG 3: 183.409 sec, 4
# spark.driver.cores_2: 183.725 sec,  AVG 2: 183.676 sec, 4
# spark.driver.cores_4: 184.997 sec,  AVG 4: 184.913 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.driver.memory : ---  1g
# spark.driver.memory_4g: 120.189 sec,  AVG 4g: 120.214 sec, 4
# spark.driver.memory_3g: 122.632 sec,  AVG 3g: 122.978 sec, 4
# spark.driver.memory_2g: 139.152 sec,  AVG 2g: 139.439 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.executor.cores : ---  1
# spark.executor.cores_4: 183.162 sec,  AVG 4: 183.566 sec, 4
# spark.executor.cores_6: 183.618 sec,  AVG 6: 183.633 sec, 4
# spark.executor.cores_2: 183.673 sec,  AVG 3: 183.697 sec, 4
# spark.executor.cores_8: 183.69 sec,  AVG 5: 183.918 sec, 4
# spark.executor.cores_5: 183.714 sec,  AVG 8: 184.011 sec, 4
# spark.executor.cores_3: 183.905 sec,  AVG 2: 184.148 sec, 4
# spark.executor.cores_7: 184.111 sec,  AVG 7: 184.501 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.executor.instances : ---  2
# spark.executor.instances_6: 183.181 sec,  AVG 8: 183.586 sec, 4
# spark.executor.instances_8: 183.351 sec,  AVG 6: 183.855 sec, 4
# spark.executor.instances_4: 183.772 sec,  AVG 3: 184.042 sec, 4
# spark.executor.instances_5: 184.053 sec,  AVG 5: 184.126 sec, 4
# spark.executor.instances_3: 184.184 sec,  AVG 7: 184.234 sec, 4
# spark.executor.instances_7: 185.125 sec,  AVG 4: 184.321 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.executor.memory : ---  1g
# spark.executor.memory_7g: 184.119 sec,  AVG 7g: 183.11 sec, 4
# spark.executor.memory_4g: 184.397 sec,  AVG 4g: 184.393 sec, 4
# spark.executor.memory_5g: 184.525 sec,  AVG 5g: 184.506 sec, 4
# spark.executor.memory_6g: 184.82 sec,  AVG 6g: 184.721 sec, 4
# spark.executor.memory_2g: 185.153 sec,  AVG 2g: 185.111 sec, 4
# spark.executor.memory_8g: 185.363 sec,  AVG 8g: 185.662 sec, 4
# default_: 185.475 sec,  AVG 3g: 186.202 sec, 4
# spark.executor.memory_3g: 185.529 sec,  AVG : 186.505 sec, 4
# ---
# spark.io.compression.codec : ---  lz4
# default_: 185.475 sec,  AVG snappy: 185.744 sec, 4
# spark.io.compression.codec_snappy: 185.61 sec,  AVG : 186.505 sec, 3
# ---
# spark.memory.fraction : ---  0.6
# spark.memory.fraction_0.4: 183.276 sec,  AVG 0.4: 183.42 sec, 3
# spark.memory.fraction_0.5: 183.808 sec,  AVG 0.5: 183.886 sec, 3
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# spark.memory.fraction_0.7: 187.675 sec,  AVG 0.7: 188.384 sec, 3
# spark.memory.fraction_0.3: 191.595 sec,  AVG 0.3: 192.644 sec, 3
# spark.memory.fraction_0.8: 198.428 sec,  AVG 0.8: 197.191 sec, 3
# ---
# spark.memory.storageFraction : ---  0.5
# spark.memory.storageFraction_0.4: 182.031 sec,  AVG 0.7: 182.439 sec, 3
# spark.memory.storageFraction_0.7: 182.733 sec,  AVG 0.4: 182.724 sec, 3
# spark.memory.storageFraction_0.3: 183.455 sec,  AVG 0.8: 183.055 sec, 3
# spark.memory.storageFraction_0.8: 184.0 sec,  AVG 0.3: 183.627 sec, 3
# spark.memory.storageFraction_0.6: 185.253 sec,  AVG 0.6: 185.501 sec, 3
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.rdd.compress : ---  false
# default_: 185.475 sec,  AVG true: 185.937 sec, 4
# spark.rdd.compress_true: 186.559 sec,  AVG : 186.505 sec, 3
# ---
# spark.reducer.maxSizeInFlight : ---  48m
# spark.reducer.maxSizeInFlight_72m: 180.852 sec,  AVG 72m: 181.033 sec, 4
# spark.reducer.maxSizeInFlight_80m: 182.859 sec,  AVG 56m: 182.972 sec, 4
# spark.reducer.maxSizeInFlight_56m: 183.146 sec,  AVG 80m: 183.11 sec, 4
# spark.reducer.maxSizeInFlight_96m: 183.293 sec,  AVG 96m: 183.39 sec, 4
# spark.reducer.maxSizeInFlight_88m: 184.002 sec,  AVG 88m: 183.781 sec, 4
# spark.reducer.maxSizeInFlight_64m: 184.323 sec,  AVG 64m: 184.399 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.rpc.message.maxSize : ---  128
# spark.rpc.message.maxSize_224: 181.309 sec,  AVG 224: 182.354 sec, 3
# spark.rpc.message.maxSize_192: 183.605 sec,  AVG 192: 183.275 sec, 3
# spark.rpc.message.maxSize_160: 184.653 sec,  AVG 160: 184.497 sec, 3
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# spark.rpc.message.maxSize_256: 187.322 sec,  AVG 256: 186.857 sec, 3
# ---
# spark.shuffle.compress : ---  true
# spark.shuffle.compress_false: 169.911 sec,  AVG false: 170.223 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.shuffle.file.buffer : ---  32k
# default_: 185.475 sec,  AVG 48k: 186.216 sec, 4
# spark.shuffle.file.buffer_48k: 186.243 sec,  AVG : 186.505 sec, 4
# spark.shuffle.file.buffer_64k: 190.579 sec,  AVG 64k: 190.463 sec, 4
# spark.shuffle.file.buffer_80k: 193.962 sec,  AVG 80k: 193.875 sec, 4
# spark.shuffle.file.buffer_96k: 196.306 sec,  AVG 96k: 196.273 sec, 4
# spark.shuffle.file.buffer_112k: 202.929 sec,  AVG 112k: 201.665 sec, 4
# spark.shuffle.file.buffer_128k: 207.005 sec,  AVG 128k: 207.018 sec, 4
# ---
# spark.shuffle.spill.compress : ---  true
# spark.shuffle.spill.compress_false: 182.052 sec,  AVG false: 182.073 sec, 4
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---
# spark.sql.shuffle.partitions : ---  100
# spark.sql.shuffle.partitions_80: 175.518 sec,  AVG 80: 175.567 sec, 3
# spark.sql.shuffle.partitions_70: 176.412 sec,  AVG 70: 177.347 sec, 3
# spark.sql.shuffle.partitions_60: 176.755 sec,  AVG 60: 177.684 sec, 3
# spark.sql.shuffle.partitions_90: 182.969 sec,  AVG 90: 182.182 sec, 3
# spark.sql.shuffle.partitions_120: 185.236 sec,  AVG 120: 185.792 sec, 3
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# spark.sql.shuffle.partitions_50: 186.253 sec,  AVG 50: 186.764 sec, 3
# spark.sql.shuffle.partitions_110: 187.082 sec,  AVG 110: 187.394 sec, 3
# spark.sql.shuffle.partitions_130: 189.518 sec,  AVG 130: 189.456 sec, 3
# spark.sql.shuffle.partitions_140: 192.595 sec,  AVG 140: 192.185 sec, 3
# ---
# spark.task.cpus : ---  1
# default_: 185.475 sec,  AVG : 186.505 sec, 4
# ---

# %%
# somewhat good result? -- handtuning sometimes selected the same parameters across both

#training_fnames
#pvals[FNAME][pname] = defa
print(training_fnames)
for pname in sorted(names):
    print(f"'{pname}': ", pvals[training_fnames[0]][pname], pvals[training_fnames[1]][pname], "AVG", pvals["AVG_"+training_fnames[0]][pname], pvals["AVG_"+training_fnames[1]][pname])
# Out:
# ['./training_results/sf10_n10_det_main0.txt', './training_results/sf10_n10_det_main_fix.txt']
# 'spark.broadcast.blockSize':  24m 6m AVG 24m 6m
# 'spark.broadcast.compress':  false false AVG false false
# 'spark.default.parallelism':  60 60 AVG 60 60
# 'spark.driver.cores':  1 3 AVG 1 3
# 'spark.driver.memory':  4g 4g AVG 4g 4g
# 'spark.executor.cores':  3 4 AVG 3 4
# 'spark.executor.instances':  2 6 AVG 2 8
# 'spark.executor.memory':  1g 7g AVG 1g 7g
# 'spark.io.compression.codec':  snappy lz4 AVG snappy snappy
# 'spark.memory.fraction':  0.5 0.4 AVG 0.5 0.4
# 'spark.memory.storageFraction':  0.6 0.4 AVG 0.6 0.7
# 'spark.rdd.compress':  true false AVG true true
# 'spark.reducer.maxSizeInFlight':  48m 72m AVG 48m 72m
# 'spark.rpc.message.maxSize':  224 224 AVG 160 224
# 'spark.shuffle.compress':  true false AVG false false
# 'spark.shuffle.file.buffer':  32k 32k AVG 32k 48k
# 'spark.shuffle.spill.compress':  true false AVG true false
# 'spark.sql.shuffle.partitions':  80 80 AVG 80 80
# 'spark.task.cpus':  1 1 AVG 1 1

# %%
# based on sf 10 results
hand_tuning10 = {
'spark.broadcast.blockSize':  '14m',
'spark.broadcast.compress':  'false',
'spark.default.parallelism':  '60',
'spark.driver.cores':  '3',
'spark.driver.memory':  '4g',
'spark.executor.cores':  '4',
'spark.executor.instances':  '8',
'spark.executor.memory':  '7g',
'spark.io.compression.codec':  'snappy',
'spark.memory.fraction':  '0.5',
'spark.memory.storageFraction':  '0.6',
'spark.rdd.compress':  'true', 
'spark.reducer.maxSizeInFlight':  '48m',
'spark.rpc.message.maxSize': '224',
'spark.shuffle.compress':  'false',
'spark.shuffle.file.buffer':  '32k',
'spark.shuffle.spill.compress':  'false', 
'spark.sql.shuffle.partitions':  '80',
'spark.task.cpus':  '1',  
}

# %%
# based on sf 1 results
hand_tuning = {
'spark.broadcast.blockSize':  '14m',
'spark.broadcast.compress':  'false',
'spark.default.parallelism':  '20',
'spark.driver.cores':  '3',
'spark.driver.memory':  '4g',
'spark.executor.cores':  '8',
'spark.executor.instances':  '8',
'spark.executor.memory':  '4g',
'spark.io.compression.codec':  'snappy',
'spark.memory.fraction':  '0.8',
'spark.memory.storageFraction':  '0.7',
'spark.rdd.compress':  'true', 
'spark.reducer.maxSizeInFlight':  '80m',
'spark.rpc.message.maxSize': '192',
'spark.shuffle.compress':  'false',
'spark.shuffle.file.buffer':  '48k',
'spark.shuffle.spill.compress':  'false', 
'spark.sql.shuffle.partitions':  '50',
'spark.task.cpus':  '1',  
}
